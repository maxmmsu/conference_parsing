# %% [markdown]
# <br><br><h3>  </h3>
# <br>
#
# <br><br><h3> A1: DEEP LEARNING </h3>
# <br>
# Regularizing Deep Convolutional Neural Networks with a Structured Decorrelation Constraint
# <br> Wei Xiong, Bo Du, Lefei Zhang, and Dacheng Tao <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Xiong%2C+Bo+Du%2C+Lefei+Zhang%2C+and+Dacheng+Tao+Regularizing+Deep+Convolutional+Neural+Networks+with+filetype:pdf
#
# Traffic Speed Prediction and Congestion Source Exploration: A Deep Learning Method
# <br> Jingyuan Wang, Qian Gu, Junjie Wu, Guannan Liu, and Zhang Xiong <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Qian+Gu%2C+Junjie+Wu%2C+Guannan+Liu%2C+and+Zhang+Xiong+Traffic+Speed+Prediction+and+filetype:pdf
#
# Model Accuracy and Runtime Tradeoff in Distributed Deep Learning: A Systematic Study
# <br> Wei Zhang, Suyog Gupta, and Fei Wang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang%2C+Suyog+Gupta%2C+and+Fei+Wang+Model+Accuracy+and+Runtime+Tradeoff+in+Distributed+Deep+filetype:pdf
#
# Convolutional MKL Based Multimodal Emotion Recognition and Sentiment Analysis
# <br> Iti Chaturvedi, Soujanya Poria, and Erik Cambria <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Chaturvedi%2C+Soujanya+Poria%2C+and+Erik+Cambria+Convolutional+MKL+Based+Multimodal+Emotion+Recognition+and+Sentiment+filetype:pdf
#
# Structure Selection for Convolutive Non-negative Matrix Factorization Using Normalized Maximum Likelihood Coding
# <br> Atsushi Suzuki, Kohei Miyaguchi, and Kenji Yamanishi <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Suzuki%2C+Kohei+Miyaguchi%2C+and+Kenji+Yamanishi+Structure+Selection+for+Convolutive+Non-negative+Matrix+Factorization+Using+filetype:pdf
#
# Product-based Neural Networks for User Response Prediction
# <br> Yanru Qu, Han Cai, Kan Ren, Weinan Zhang, and Yong Yu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Qu%2C+Han+Cai%2C+Kan+Ren%2C+Weinan+Zhang%2C+and+Yong+Yu+Product-based+Neural+Networks+for+filetype:pdf
#
# Deep Convolutional Factor Analyser for Multivariate Time Series Modeling
# <br> Chao Yuan <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Yuan+Deep+Convolutional+Factor+Analyser+for+Multivariate+Time+Series+Modeling+filetype:pdf
#
# Learning Deep Networks from Noisy Labels with Dropout Regularization
# <br> Ishan Jindal, Matthew Nokleby, and Xuewen Chen <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Jindal%2C+Matthew+Nokleby%2C+and+Xuewen+Chen+Learning+Deep+Networks+from+Noisy+Labels+with+Dropout+filetype:pdf
#
#
# <br><br><h3> B1: PATTERNS </h3>
# <br>
# A Scalable and Generic framework to Mine Top-k Representative Subgraph Patterns"
# <br> Dheepikaa Natarajan and Sayan Ranu  <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Natarajan+and+Sayan+Ranu++A+Scalable+and+Generic+framework+to+Mine+Top-k+Representative+filetype:pdf
#
# CoreScope: Graph Mining Using k-Core Analysis - Patterns, Anomalies, and Algorithms"
# <br> Kijung Shin, Tina Eliassi-Rad, and Christos Faloutsos  <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Shin%2C+Tina+Eliassi-Rad%2C+and+Christos+Faloutsos++CoreScope%3A+Graph+Mining+Using+k-Core+Analysis+-+filetype:pdf
#
# Mining Graphlet Counts in Online Social Networks"
# <br> Xiaowei Chen and John C. S. Lui  <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Chen+and+John+C.+S.+Lui++Mining+Graphlet+Counts+in+Online+Social+Networks%22+filetype:pdf
#
# On Efficient External-Memory Triangle Listing"
# <br> Yi Cui, Di Xiao, and Dmitri Loguinov  <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Cui%2C+Di+Xiao%2C+and+Dmitri+Loguinov++On+Efficient+External-Memory+Triangle+Listing%22+filetype:pdf
#
# Bi-level Rare Temporal Pattern Detection"
# <br> Dawei Zhou, Jingrui He, Yu Cao, and Jae-sun Seo  <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhou%2C+Jingrui+He%2C+Yu+Cao%2C+and+Jae-sun+Seo++Bi-level+Rare+Temporal+Pattern+Detection%22+filetype:pdf
#
# Direct Mining of Subjectively Interesting Relational Patterns"
# <br> Tias Guns, Achille Aknin, Jefrey Lijffijt, and Tijl De Bie  <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Guns%2C+Achille+Aknin%2C+Jefrey+Lijffijt%2C+and+Tijl+De+Bie++Direct+Mining+of+Subjectively+filetype:pdf
#
# Mining Statistically Significant Attribute Associations in Attributed Graphs"
# <br> Jihwan Lee, Keehwan Park, and Sunil Prabhakar  <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Lee%2C+Keehwan+Park%2C+and+Sunil+Prabhakar++Mining+Statistically+Significant+Attribute+Associations+in+Attributed+filetype:pdf
#
#
# <br><br><h3> C1: URBAN AND MOBILITY DATA </h3>
# <br>
# Unsupervised Exceptional Attributed Sub-graph Mining in Urban Data
# <br> Anes Bendimerad, Marc Plantevit, and Céline Robardet <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Bendimerad%2C+Marc+Plantevit%2C+and+C%C3%A9line+Robardet+Unsupervised+Exceptional+Attributed+Sub-graph+Mining+in+Urban+Data+filetype:pdf
#
# POI Recommendation: A Temporal Matching between POI Popularity and User Regularity
# <br> Zijun Yao, Yanjie Fu, Bin Liu, Yanchi Liu, and Hui Xiong <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Yao%2C+Yanjie+Fu%2C+Bin+Liu%2C+Yanchi+Liu%2C+and+Hui+Xiong+POI+Recommendation%3A+A+Temporal+filetype:pdf
#
# The Optimal Distribution of Electric-Vehicle Chargers across A City
# <br> Chen Liu, Ke Deng, Chaojie Li, Jianxin Li, Yanhua Li, and Jun Luo <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Liu%2C+Ke+Deng%2C+Chaojie+Li%2C+Jianxin+Li%2C+Yanhua+Li%2C+and+Jun+Luo+The+Optimal+filetype:pdf
#
# Relief of Spatiotemporal Accessibility Overloading with Optimal Resource Placement
# <br> Chien-Wei Chang, Hao-Yi Chih, Dean Chou, Yu-Chen Shu, and Kun-Ta Chuang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Chang%2C+Hao-Yi+Chih%2C+Dean+Chou%2C+Yu-Chen+Shu%2C+and+Kun-Ta+Chuang+Relief+of+Spatiotemporal+Accessibility+filetype:pdf
#
# The Development of a Smart Taxicab Scheduling System: A Multi-Source Data Fusion Perspective
# <br> Yang Wang, Binxin Liang, Zheng Wei, Liusheng Huang, and Hengchang Liu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Binxin+Liang%2C+Zheng+Wei%2C+Liusheng+Huang%2C+and+Hengchang+Liu+The+Development+of+a+filetype:pdf
#
# Regularized Content-Aware Tensor Factorization Meets Temporal-Aware Location Recommendation
# <br> Defu Lian, Zhengyu Zhang, Yong Ge, Fuzheng Zhang, Nicholas Jing Yuan, and Xing Xie <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Lian%2C+Zhengyu+Zhang%2C+Yong+Ge%2C+Fuzheng+Zhang%2C+Nicholas+Jing+Yuan%2C+and+Xing+Xie+Regularized+filetype:pdf
#
# Modeling Real Estate for School District Identification
# <br> Fei Tan, Chaoran Cheng, and Zhi Wei <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Tan%2C+Chaoran+Cheng%2C+and+Zhi+Wei+Modeling+Real+Estate+for+School+District+Identification+filetype:pdf
#
# House Price Modeling over Heterogeneous Regions with Hierarchical Spatial Functional Analysis
# <br> Bang Liu, Borislalv Mavrin, Di Niu, and Linglong Kong <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Liu%2C+Borislalv+Mavrin%2C+Di+Niu%2C+and+Linglong+Kong+House+Price+Modeling+over+Heterogeneous+Regions+filetype:pdf
#
#
# <br><br><h3> TUTORIAL </h3>
# <br>
#
# <br><br><h3> 1 </h3>
# <br>
#
# <br><br><h3> A2: CLUSTERING </h3>
# <br>
# Generalized Independent Subspace Clustering
# <br> Wei Ye, Samuel Maurus, Nina Hubig, and Claudia Plant <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Ye%2C+Samuel+Maurus%2C+Nina+Hubig%2C+and+Claudia+Plant+Generalized+Independent+Subspace+Clustering+filetype:pdf
#
# Robust Graph-theoretic Clustering Approaches Using Node-Based Resilience Measures
# <br> John Matta, Jeffrey Borwey, Tayo Obafemi-Ajayi, Donald Wunsch, and Gunes Ercal <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Matta%2C+Jeffrey+Borwey%2C+Tayo+Obafemi-Ajayi%2C+Donald+Wunsch%2C+and+Gunes+Ercal+Robust+Graph-theoretic+Clustering+Approaches+filetype:pdf
#
# Multi-Type Co-clustering of General Heterogeneous Information Networks
# <br> Xianchao Zhang, Haixin Li, Wenxin Liang, and Jiebo Luo <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang%2C+Haixin+Li%2C+Wenxin+Liang%2C+and+Jiebo+Luo+Multi-Type+Co-clustering+of+General+Heterogeneous+Information+filetype:pdf
#
# Interpretable Clustering via Discriminative Rectangle Mixture Model
# <br> Junxiang Chen, Yale Chang, Brian Hobbs, Peter Castaldi, Michael Cho, Edwin Silverman, and Jennifer Dy <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Chen%2C+Yale+Chang%2C+Brian+Hobbs%2C+Peter+Castaldi%2C+Michael+Cho%2C+Edwin+Silverman%2C+and+Jennifer+Dy+filetype:pdf
#
# Self-Grouping Multi-Network Clustering
# <br> Jingchao Ni, Wei Cheng, Wei Fan, and Xiang Zhang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Ni%2C+Wei+Cheng%2C+Wei+Fan%2C+and+Xiang+Zhang+Self-Grouping+Multi-Network+Clustering+filetype:pdf
#
# A Theoretical Analysis of the Fuzzy K-Means Problem
# <br> Johannes Blömer, Sascha Brauer, and Kathrin Bujna <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Bl%C3%B6mer%2C+Sascha+Brauer%2C+and+Kathrin+Bujna+A+Theoretical+Analysis+of+the+Fuzzy+K-Means+Problem+filetype:pdf
#
# Multi-View Clustering via Concept Factorization with Local Manifold Regularization
# <br> Hao Wang, Yan Yang, and Tianrui Li <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Yan+Yang%2C+and+Tianrui+Li+Multi-View+Clustering+via+Concept+Factorization+with+Local+Manifold+filetype:pdf
#
# Robust Convex Clustering Analysis
# <br> Qi Wang, Pinghua Gong, Shiyu Chang, Thomas Huang, and Jiayu Zhou <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Pinghua+Gong%2C+Shiyu+Chang%2C+Thomas+Huang%2C+and+Jiayu+Zhou+Robust+Convex+Clustering+Analysis+filetype:pdf
#
#
# <br><br><h3> B2: RECOMMENDER SYSTEMS </h3>
# <br>
# Efficient Rectangular Maximal-Volume Algorithm for Rating Elicitation in Collaborative Filtering
# <br> Alexander Fonarev, Alexander Mikhalev, Gleb Gusev, Ivan Oseledets, and Pavel Serdyukov <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Fonarev%2C+Alexander+Mikhalev%2C+Gleb+Gusev%2C+Ivan+Oseledets%2C+and+Pavel+Serdyukov+Efficient+Rectangular+Maximal-Volume+Algorithm+filetype:pdf
#
# Recommending Packages to Groups
# <br> Shuyao Qi, Nikos Mamoulis, Evaggelia Pitoura, and Panayiotis Tsaparas <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Qi%2C+Nikos+Mamoulis%2C+Evaggelia+Pitoura%2C+and+Panayiotis+Tsaparas+Recommending+Packages+to+Groups+filetype:pdf
#
# Fusing Similarity Models with Markov Chains for Sparse Sequential Recommendation
# <br> Ruining He and Julian McAuley <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=He+and+Julian+McAuley+Fusing+Similarity+Models+with+Markov+Chains+for+Sparse+Sequential+Recommendation+filetype:pdf
#
# Context-aware Sequential Recommendation
# <br> Qiang Liu, Shu Wu, and Liang Wang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Liu%2C+Shu+Wu%2C+and+Liang+Wang+Context-aware+Sequential+Recommendation+filetype:pdf
#
# Learning Compatibility Across Categories for Heterogeneous Item Recommendation
# <br> Ruining He, Charles Packer, and Julian McAuley <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=He%2C+Charles+Packer%2C+and+Julian+McAuley+Learning+Compatibility+Across+Categories+for+Heterogeneous+Item+Recommendation+filetype:pdf
#
# Time-Aware User Identification with Topic Models
# <br> Clément Lesaege, François Schnitzler, Anne Lambert, and Jean-Ronan Vigouroux <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Lesaege%2C+Fran%C3%A7ois+Schnitzler%2C+Anne+Lambert%2C+and+Jean-Ronan+Vigouroux+Time-Aware+User+Identification+with+Topic+Models+filetype:pdf
#
# Whether this participant will attract you to this event? Exploiting Participant Influence for Event Recommendation
# <br> Yi Liao, Xinshi Lin, and Wai Lam <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Liao%2C+Xinshi+Lin%2C+and+Wai+Lam+Whether+this+participant+will+attract+you+to+this+filetype:pdf
#
#
# <br><br><h3> C2: EVENTS AND SOCIAL </h3>
# <br>
# Multi-resolution Spatial Event Forecasting in Social Media
# <br> Liang Zhao, Feng Chen, Chang-Tien Lu, and Naren Ramakrishnan <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhao%2C+Feng+Chen%2C+Chang-Tien+Lu%2C+and+Naren+Ramakrishnan+Multi-resolution+Spatial+Event+Forecasting+in+Social+filetype:pdf
#
# Event Series Prediction via Non-Homogeneous Poisson Process Modelling
# <br> James Goulding, Simon Preston, and Gavin Smith <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Goulding%2C+Simon+Preston%2C+and+Gavin+Smith+Event+Series+Prediction+via+Non-Homogeneous+Poisson+Process+Modelling+filetype:pdf
#
# Towards Scalable Network Delay Minimization
# <br> Sourav Medya, Petko Bogdanov, and Ambuj K Singh <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Medya%2C+Petko+Bogdanov%2C+and+Ambuj+K+Singh+Towards+Scalable+Network+Delay+Minimization+filetype:pdf
#
# Detecting Change Processes in Dynamic Networks by Frequent Graph Evolution Rule Mining
# <br> Erik Scharwaechter, Marwan Hassani, Emmanuel Mueller, Thomas Seidl, and Jonathan Donges <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Scharwaechter%2C+Marwan+Hassani%2C+Emmanuel+Mueller%2C+Thomas+Seidl%2C+and+Jonathan+Donges+Detecting+Change+Processes+in+filetype:pdf
#
# DeBot: Twitter Bot Detection via Warped Correlation
# <br> Nikan Chavoshi, Hossein Hamooni, and Abdullah Mueen <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Chavoshi%2C+Hossein+Hamooni%2C+and+Abdullah+Mueen+DeBot%3A+Twitter+Bot+Detection+via+Warped+Correlation+filetype:pdf
#
# Modeling Knowledge Diffusion with Time Lags in Citation Networks
# <br> Tao-yang Fu, Zhen Lei, and Wang-Chien Lee <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Fu%2C+Zhen+Lei%2C+and+Wang-Chien+Lee+Modeling+Knowledge+Diffusion+with+Time+Lags+in+Citation+filetype:pdf
#
# Event Grounding from Multimodal Social Network Fusion
# <br> Hyunsouk Cho, Jinyoung Yeo, and Seung-won Hwang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Cho%2C+Jinyoung+Yeo%2C+and+Seung-won+Hwang+Event+Grounding+from+Multimodal+Social+Network+Fusion+filetype:pdf
#
# Large-Scale Embedding Learning in Heterogeneous Event Data
# <br> Huan Gui, Jialu Liu, Fangbo Tao, Meng Jiang, Brandon Norick, and Jiawei Han <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Gui%2C+Jialu+Liu%2C+Fangbo+Tao%2C+Meng+Jiang%2C+Brandon+Norick%2C+and+Jiawei+Han+Large-Scale+Embedding+filetype:pdf
#
#
# <br><br><h3> TUTORIAL </h3>
# <br>
#
# <br><br><h3> 1 </h3>
# <br>
#
# <br><br><h3> A3: UNSUPERVISED LEARNING </h3>
# <br>
# Iteratively Reweighted Least Squares Algorithms for L1-Norm Principal Component Analysis
# <br> Young Woong Park and Diego Klabjan <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Woong+Park+and+Diego+Klabjan+Iteratively+Reweighted+Least+Squares+Algorithms+for+L1-Norm+Principal+Component+filetype:pdf
#
# Heterogeneous Representation Learning with Structured Sparsity Regularization
# <br> Pei Yang and Jingrui He <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Yang+and+Jingrui+He+Heterogeneous+Representation+Learning+with+Structured+Sparsity+Regularization+filetype:pdf
#
# Triply Stochastic Variational Inference for Non-linear Beta Process Factor Analysis
# <br> Kai Fan, Yizhe Zhang, and Katherine Heller <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Fan%2C+Yizhe+Zhang%2C+and+Katherine+Heller+Triply+Stochastic+Variational+Inference+for+Non-linear+Beta+Process+filetype:pdf
#
# Causal Inference by Compression
# <br> Kailash Budhathoki and Jilles Vreeken <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Budhathoki+and+Jilles+Vreeken+Causal+Inference+by+Compression+filetype:pdf
#
# Factorizing Complex Discrete Data "with Finesse"
# <br> Samuel Maurus and Claudia Plant <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Maurus+and+Claudia+Plant+Factorizing+Complex+Discrete+Data+%22with+Finesse%22+filetype:pdf
#
# A Fast Factorization-based Approach to Robust Principal Component Analysis
# <br> Chong Peng, Zhao Kang, and Qiang Cheng <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Peng%2C+Zhao+Kang%2C+and+Qiang+Cheng+A+Fast+Factorization-based+Approach+to+Robust+Principal+Component+filetype:pdf
#
#
# <br><br><h3> B3: CROWDS </h3>
# <br>
# A Bayesian Nonparametric Approach to Dynamic Dyadic Data Prediction
# <br> Fengyuan Zhu, Guangyong Chen, and Pheng-Ann Heng <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhu%2C+Guangyong+Chen%2C+and+Pheng-Ann+Heng+A+Bayesian+Nonparametric+Approach+to+Dynamic+Dyadic+Data+filetype:pdf
#
# Modeling Ambiguity, Subjectivity, and Diverging Viewpoints in Opinion Question Answering Systems
# <br> Mengting Wan and Julian McAuley <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wan+and+Julian+McAuley+Modeling+Ambiguity%2C+Subjectivity%2C+and+Diverging+Viewpoints+in+Opinion+Question+Answering+filetype:pdf
#
# Group Preference Aggregation: A Nash Equilibrium Approach
# <br> Hongke Zhao, Qi Liu, and Yong Ge <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhao%2C+Qi+Liu%2C+and+Yong+Ge+Group+Preference+Aggregation%3A+A+Nash+Equilibrium+Approach+filetype:pdf
#
# Binding Pairwise Preferences of the Crowd into Rankings: A Thurstonian Approach
# <br> Xiaolong Wang, Jingjing Wang, Jie Luo, Yi Chang, and Chengxiang Zhai <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Jingjing+Wang%2C+Jie+Luo%2C+Yi+Chang%2C+and+Chengxiang+Zhai+Binding+Pairwise+Preferences+of+filetype:pdf
#
# Improved and Scalable Bradley-Terry Model for Collaborative Ranking
# <br> Jun Hu and Ping li <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Hu+and+Ping+li+Improved+and+Scalable+Bradley-Terry+Model+for+Collaborative+Ranking+filetype:pdf
#
# A Robust Framework for Classifying Evolving Document Streams in an Expert-Machine-Crowd Setting
# <br> Muhammad Imran, Sanjay Chawla, and Carlos Castillo <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Imran%2C+Sanjay+Chawla%2C+and+Carlos+Castillo+A+Robust+Framework+for+Classifying+Evolving+Document+Streams+filetype:pdf
#
#
# <br><br><h3> C3: TEXT </h3>
# <br>
# Learning Hierarchically Decomposable Concepts with Active Over-Labeling
# <br> Yuji Mo, Stephen Scott, and Doug Downey <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Mo%2C+Stephen+Scott%2C+and+Doug+Downey+Learning+Hierarchically+Decomposable+Concepts+with+Active+Over-Labeling+filetype:pdf
#
# L-EnsNMF: Boosted Local Topic Discovery via Ensemble of Nonnegative Matrix Factorization
# <br> Sangho Suh, Jaegul Choo, Joonseok Lee, and Chandan Reddy <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Suh%2C+Jaegul+Choo%2C+Joonseok+Lee%2C+and+Chandan+Reddy+L-EnsNMF%3A+Boosted+Local+Topic+Discovery+via+filetype:pdf
#
# Mutual Reinforcement of Academic Performance Prediction and Library Book Recommendation
# <br> Defu Lian, Qi Liu, Wenya Zhu, Xing Xie, and Hui Xiong <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Lian%2C+Qi+Liu%2C+Wenya+Zhu%2C+Xing+Xie%2C+and+Hui+Xiong+Mutual+Reinforcement+of+Academic+filetype:pdf
#
# Topic Discovery for Short Texts Using Word Embeddings
# <br> Guangxu Xun, Vishrawas Gopalakrishnan, Fenglong Ma, Yaliang Li, Jing Gao, and Aidong Zhang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Xun%2C+Vishrawas+Gopalakrishnan%2C+Fenglong+Ma%2C+Yaliang+Li%2C+Jing+Gao%2C+and+Aidong+Zhang+Topic+Discovery+filetype:pdf
#
# Concept based Short Text Stream Classification with Topic Drifting Detection
# <br> Peipei Li, Lu He, Xuegang Hu, Yuhong Zhang, Lei Li, and Xindong Wu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Li%2C+Lu+He%2C+Xuegang+Hu%2C+Yuhong+Zhang%2C+Lei+Li%2C+and+Xindong+Wu+Concept+based+filetype:pdf
#
# A Scalable Framework for Stylometric Analysis Query Processing
# <br> Sarana Nutanong, chenyun YU, Raheem Sarwar, Peter Xu, and Dickson Chow <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Nutanong%2C+chenyun+YU%2C+Raheem+Sarwar%2C+Peter+Xu%2C+and+Dickson+Chow+A+Scalable+Framework+for+filetype:pdf
#
# Incorporating Pre-Training in Long Short-Term Memory Networks for Tweets Classification
# <br> Shuhan Yuan, Xintao Wu, and Yang Xiang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Yuan%2C+Xintao+Wu%2C+and+Yang+Xiang+Incorporating+Pre-Training+in+Long+Short-Term+Memory+Networks+for+filetype:pdf
#
# Canonical Consistent Weighted Sampling for Real-Value Weighted Min-Hash
# <br> Wei Wu, Bin Li, Ling Chen, and Chengqi Zhang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wu%2C+Bin+Li%2C+Ling+Chen%2C+and+Chengqi+Zhang+Canonical+Consistent+Weighted+Sampling+for+Real-Value+filetype:pdf
#
#
# <br><br><h3> TUTORIAL </h3>
# <br>
#
# <br><br><h3> 2 </h3>
# <br>
#
# <br><br><h3> A4: THEORY </h3>
# <br>
# From Sets of Good Redescriptions to Good Sets of Redescriptions
# <br> Janis Kalofolias, Esther Galbrun, and Pauli Miettinen <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Kalofolias%2C+Esther+Galbrun%2C+and+Pauli+Miettinen+From+Sets+of+Good+Redescriptions+to+Good+Sets+filetype:pdf
#
# What Will You Gain By Rounding: Theory and Algorithms for Rounding Rank
# <br> Stefan Neumann, Rainer Gemulla, and Pauli Miettinen <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Neumann%2C+Rainer+Gemulla%2C+and+Pauli+Miettinen+What+Will+You+Gain+By+Rounding%3A+Theory+and+filetype:pdf
#
# ADAGIO: Fast Data-aware Near-Isometric Linear Embeddings
# <br> Jaroslaw Blasiok and Charalampos Tsourakakis <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Blasiok+and+Charalampos+Tsourakakis+ADAGIO%3A+Fast+Data-aware+Near-Isometric+Linear+Embeddings+filetype:pdf
#
# Aligned Matrix Completion: Integrating Consistency and Independency in Multiple Domains
# <br> Linli Xu and Zaiyi Chen <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Xu+and+Zaiyi+Chen+Aligned+Matrix+Completion%3A+Integrating+Consistency+and+Independency+in+Multiple+Domains+filetype:pdf
#
# Communities in Preference Networks: Refined Axioms and Beyond
# <br> Gang Zeng, Yuyi Wang, Juhua Pu, Xingwu Liu, Xiaoming Sun, and Jialin Zhang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zeng%2C+Yuyi+Wang%2C+Juhua+Pu%2C+Xingwu+Liu%2C+Xiaoming+Sun%2C+and+Jialin+Zhang+Communities+in+filetype:pdf
#
# Foundations of Perturbation Robust Clustering
# <br> Jarrod Moore and Margareta Ackerman <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Moore+and+Margareta+Ackerman+Foundations+of+Perturbation+Robust+Clustering+filetype:pdf
#
# Compressing Random Forests
# <br> Amichai Painsky and Saharon Rosset <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Painsky+and+Saharon+Rosset+Compressing+Random+Forests+filetype:pdf
#
#
# <br><br><h3> C4: WEB </h3>
# <br>
# Reliable Gender Prediction Based on Users' Video Viewing Behavior
# <br> Jie Zhang, Kuang Du, Ruihua Cheng, Zhi Wei, Chenguang Qin, Huaxin You, and Sha Hu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang%2C+Kuang+Du%2C+Ruihua+Cheng%2C+Zhi+Wei%2C+Chenguang+Qin%2C+Huaxin+You%2C+and+Sha+Hu+filetype:pdf
#
# Efficient Extraction of Non-negative Latent Factors from High-dimensional and Sparse Matrices
# <br> Xin Luo, Mingsheng Shang, and Shuai Li <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Luo%2C+Mingsheng+Shang%2C+and+Shuai+Li+Efficient+Extraction+of+Non-negative+Latent+Factors+from+High-dimensional+filetype:pdf
#
# Inferring latent network from cascade data for dynamic social recommendation
# <br> Qin Zhang, Jia Wu, Peng Zhang, Guodong Long, Ivor W. Tsang, and Chengqi Zhang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang%2C+Jia+Wu%2C+Peng+Zhang%2C+Guodong+Long%2C+Ivor+W.+Tsang%2C+and+Chengqi+Zhang+Inferring+filetype:pdf
#
# Sparse Factorization Machines for Click-through Rate Prediction
# <br> Zhen Pan, Qi Liu, Tong Xu, Enhong Chen, Haiping Ma, and Hongjie Lin <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Pan%2C+Qi+Liu%2C+Tong+Xu%2C+Enhong+Chen%2C+Haiping+Ma%2C+and+Hongjie+Lin+Sparse+Factorization+filetype:pdf
#
# Meta Analyses for Dynamic Contextual Multi Arm Bandits in Display Advertisement
# <br> Hongxia Yang and Quan Lu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Yang+and+Quan+Lu+Meta+Analyses+for+Dynamic+Contextual+Multi+Arm+Bandits+in+Display+filetype:pdf
#
# Selecting Valuable Customers for Merchants in E-commerce Platforms
# <br> Yijun Wang, Le Wu, Zongda Wu, Enhong Chen, and Qi Liu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Le+Wu%2C+Zongda+Wu%2C+Enhong+Chen%2C+and+Qi+Liu+Selecting+Valuable+Customers+for+filetype:pdf
#
# Service Usage Analysis in Mobile Messaging Apps: A Multi-Label Multi-View Perspective
# <br> Hui Xiong, Junming Liu, Xinjiang Lu, Yanjie Fu, and Xiaolin Li <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Xiong%2C+Junming+Liu%2C+Xinjiang+Lu%2C+Yanjie+Fu%2C+and+Xiaolin+Li+Service+Usage+Analysis+in+filetype:pdf
#
#
# <br><br><h3> B4: SUPERVISED LEARNING 1 </h3>
# <br>
# Asynchronous Multi-Task Learning
# <br> Inci Baytas, Ming Yan, Anil Jain, and Jiayu Zhou <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Baytas%2C+Ming+Yan%2C+Anil+Jain%2C+and+Jiayu+Zhou+Asynchronous+Multi-Task+Learning+filetype:pdf
#
# Interactive Multi-Task Relationship Learning
# <br> Kaixiang Lin and Jiayu Zhou <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Lin+and+Jiayu+Zhou+Interactive+Multi-Task+Relationship+Learning+filetype:pdf
#
# Functional Regression with Mode-Sparsity Constraint
# <br> Pei Yang and Jingrui He <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Yang+and+Jingrui+He+Functional+Regression+with+Mode-Sparsity+Constraint+filetype:pdf
#
# Learning Supervised Binary Hashing: Optimization vs Diversity
# <br> Ramin Raziperchikolaei and Miguel Carreira-Perpinan <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Raziperchikolaei+and+Miguel+Carreira-Perpinan+Learning+Supervised+Binary+Hashing%3A+Optimization+vs+Diversity+filetype:pdf
#
# Bayesian Rule Sets for Interpretable Classification
# <br> Tong Wang, Cynthia Rudin, Finale Doshi-Velez, Yimin Liu, Erica Klampfl, and Perry MacNeille <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Cynthia+Rudin%2C+Finale+Doshi-Velez%2C+Yimin+Liu%2C+Erica+Klampfl%2C+and+Perry+MacNeille+Bayesian+Rule+filetype:pdf
#
# Probabilistic Formulations of Regression with Mixed Guidance
# <br> Aubrey Gress and Ian Davidson <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Gress+and+Ian+Davidson+Probabilistic+Formulations+of+Regression+with+Mixed+Guidance+filetype:pdf
#
# Background Check: A general technique to build more reliable and versatile classifiers
# <br> Miquel Nieto, Telmo Silva Filho, Meelis Kull, and Peter Flach <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Nieto%2C+Telmo+Silva+Filho%2C+Meelis+Kull%2C+and+Peter+Flach+Background+Check%3A+A+general+technique+filetype:pdf
#
# Optimizing the Multi-class F-measure via Biconcave Programming
# <br> Weiwei Pan, Harikrishna Narasimhan, Purushottam Kar, Pavlos Protopapas, and Harish Ramaswamy <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Pan%2C+Harikrishna+Narasimhan%2C+Purushottam+Kar%2C+Pavlos+Protopapas%2C+and+Harish+Ramaswamy+Optimizing+the+Multi-class+F-measure+filetype:pdf
#
# A Rotation Invariant Latent Factor Model for Moveme Discovery from Static Poses
# <br> Matteo Ruggero Ronchi, Joon Sik Kim, and Yisong Yue <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Ruggero+Ronchi%2C+Joon+Sik+Kim%2C+and+Yisong+Yue+A+Rotation+Invariant+Latent+Factor+Model+filetype:pdf
#
#
# <br><br><h3> TUTORIAL </h3>
# <br>
#
# <br><br><h3> 3 </h3>
# <br>
#
# <br><br><h3> A5: GRAPHS 1 </h3>
# <br>
# Waddling Random Walk: Fast and Accurate Mining of Motif Statistics in Large Graphs
# <br> Guyue Han and Harish Sethu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Han+and+Harish+Sethu+Waddling+Random+Walk%3A+Fast+and+Accurate+Mining+of+Motif+Statistics+filetype:pdf
#
# Random Walk with Restart over Dynamic Graphs
# <br> Weiren Yu and Weiren Yu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Yu+and+Weiren+Yu+Random+Walk+with+Restart+over+Dynamic+Graphs+filetype:pdf
#
# Edge Weight Prediction in Weighted Signed Networks
# <br> Srijan Kumar, Francesca Spezzano, V.S. Subrahmanian, and Christos Faloutsos <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Kumar%2C+Francesca+Spezzano%2C+V.S.+Subrahmanian%2C+and+Christos+Faloutsos+Edge+Weight+Prediction+in+Weighted+Signed+filetype:pdf
#
# Personalized Ranking in Signed Networks using Signed Random Walk with Restart
# <br> Jinhong Jung, Woojeong Jin, Sael Lee, and U Kang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Jung%2C+Woojeong+Jin%2C+Sael+Lee%2C+and+U+Kang+Personalized+Ranking+in+Signed+Networks+using+filetype:pdf
#
# Asymptotic Analysis of Equivalences and Core-Structures in Kronecker-Style Graph Models
# <br> Alex Chin, Timothy Goodrich, Michael O'Brien, Felix Reidl, Blair Sullivan, and Drew van der Poel <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Chin%2C+Timothy+Goodrich%2C+Michael+O%27Brien%2C+Felix+Reidl%2C+Blair+Sullivan%2C+and+Drew+van+der+Poel+filetype:pdf
#
# Fractality of Massive Graphs: Scalable Analysis with Sketch-Based Box-Covering Algorithm
# <br> Takuya Akiba, Kenko Nakamura, and Taro Takaguchi <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Akiba%2C+Kenko+Nakamura%2C+and+Taro+Takaguchi+Fractality+of+Massive+Graphs%3A+Scalable+Analysis+with+Sketch-Based+filetype:pdf
#
# Cut Tree Construction from Massive Graphs
# <br> Takuya Akiba, Yoichi Iwata, Yosuke Sameshima, Naoto Mizuno, and Yosuke Yano <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Akiba%2C+Yoichi+Iwata%2C+Yosuke+Sameshima%2C+Naoto+Mizuno%2C+and+Yosuke+Yano+Cut+Tree+Construction+from+filetype:pdf
#
#
# <br><br><h3> B5: FEATURE SELECTION </h3>
# <br>
# Robust Multi-View Feature Selection
# <br> Hongfu Liu, Haiyi Mao, and Yun Fu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Liu%2C+Haiyi+Mao%2C+and+Yun+Fu+Robust+Multi-View+Feature+Selection+filetype:pdf
#
# A Fast Iterative Algorithm for Improved Unsupervised Feature Selection
# <br> Bruno Ordozgoiti, Sandra Gómez Canaval, and Alberto Mozo <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Ordozgoiti%2C+Sandra+G%C3%B3mez+Canaval%2C+and+Alberto+Mozo+A+Fast+Iterative+Algorithm+for+Improved+Unsupervised+filetype:pdf
#
# Unsupervised Feature Selection for Outlier Detection by Modelling Hierarchical Value-Feature Couplings
# <br> Guansong Pang, Longbing Cao, Ling Chen, and Huan Liu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Pang%2C+Longbing+Cao%2C+Ling+Chen%2C+and+Huan+Liu+Unsupervised+Feature+Selection+for+Outlier+Detection+filetype:pdf
#
# Feature Grouping using Weighted l1 norm for High-Dimensional Data
# <br> Bhanukiran Vinzamuri, Karthik Padthe, and Chandan Reddy <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Vinzamuri%2C+Karthik+Padthe%2C+and+Chandan+Reddy+Feature+Grouping+using+Weighted+l1+norm+for+High-Dimensional+filetype:pdf
#
# Toward Time-Evolving Feature Selection on Dynamic Networks
# <br> Jundong Li, Xia Hu, Ling Jian, and Huan Liu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Li%2C+Xia+Hu%2C+Ling+Jian%2C+and+Huan+Liu+Toward+Time-Evolving+Feature+Selection+on+Dynamic+filetype:pdf
#
# Online Unsupervised Multi-view Feature Selection
# <br> Weixiang Shao, Lifang He, Chun-Ta Lu, Xiaokai Wei, and Philip Yu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Shao%2C+Lifang+He%2C+Chun-Ta+Lu%2C+Xiaokai+Wei%2C+and+Philip+Yu+Online+Unsupervised+Multi-view+Feature+filetype:pdf
#
# ExploreKit: Automatic Feature Generation and Selection
# <br> Gilad Katz, Richard Shin, and Dawn Song <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Katz%2C+Richard+Shin%2C+and+Dawn+Song+ExploreKit%3A+Automatic+Feature+Generation+and+Selection+filetype:pdf
#
#
# <br><br><h3> C5: PRIVACY </h3>
# <br>
# Beyond Points and Paths: Counting Private Bodies
# <br> Maryam Fanaeepour and Benjamin Rubinstein <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Fanaeepour+and+Benjamin+Rubinstein+Beyond+Points+and+Paths%3A+Counting+Private+Bodies+filetype:pdf
#
# Differentially Private Regression Diagnostics
# <br> Yan Chen, Ashwin Machanavajjhala, Jerome Reiter, and Andres Barrientos <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Chen%2C+Ashwin+Machanavajjhala%2C+Jerome+Reiter%2C+and+Andres+Barrientos+Differentially+Private+Regression+Diagnostics+filetype:pdf
#
# Auditing Black-box Models for Indirect Influence
# <br> Philip Adler, Casey Falk, Sorelle Friedler, Gabriel Rybeck, Carlos Schedegger, Brandon Smith, and Suresh Venkatasubramanian <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Adler%2C+Casey+Falk%2C+Sorelle+Friedler%2C+Gabriel+Rybeck%2C+Carlos+Schedegger%2C+Brandon+Smith%2C+and+Suresh+Venkatasubramanian+filetype:pdf
#
# College Student Scholarships and Subsidies Granting: A Multi-Modal Multi-Label Approach
# <br> Han-Jia Ye, De-Chuan Zhan, Xiaolin Li, Zhen-Chuan Huang, and Yuan Jiang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Ye%2C+De-Chuan+Zhan%2C+Xiaolin+Li%2C+Zhen-Chuan+Huang%2C+and+Yuan+Jiang+College+Student+Scholarships+and+filetype:pdf
#
# Differential Location Privacy for Sparse Mobile Crowdsensing
# <br> Leye Wang, Daqing Zhang, Dingqi Yang, Brian Y. Lim, and Xiaojuan Ma <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Daqing+Zhang%2C+Dingqi+Yang%2C+Brian+Y.+Lim%2C+and+Xiaojuan+Ma+Differential+Location+Privacy+filetype:pdf
#
# Scalable Block Scheduling for Efficient Multi-Database Record Linkage
# <br> Thilina Ranbaduge, Dinusha Vatsalan, and Peter Christen <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Ranbaduge%2C+Dinusha+Vatsalan%2C+and+Peter+Christen+Scalable+Block+Scheduling+for+Efficient+Multi-Database+Record+Linkage+filetype:pdf
#
#
# <br><br><h3> TUTORIAL </h3>
# <br>
#
# <br><br><h3> 3 </h3>
# <br>
#
# <br><br><h3> C6: ANOMALIES AND OUTLIERS </h3>
# <br>
# Probabilistic-Mismatch Anomaly Detection: Do one's Medications Match with the Diagnoses?
# <br> Lingxiao Zhang, Xiang Li, Heifeng Liu, Jing Mei, Gang Hu, Junfeng Zhao, Bing Xie, and Guotong Xie <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang%2C+Xiang+Li%2C+Heifeng+Liu%2C+Jing+Mei%2C+Gang+Hu%2C+Junfeng+Zhao%2C+Bing+Xie%2C+and+filetype:pdf
#
# Regularized Large Margin Distance Metric Learning
# <br> Ya Li, Xinmei Tian, and Dacheng Tao <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Li%2C+Xinmei+Tian%2C+and+Dacheng+Tao+Regularized+Large+Margin+Distance+Metric+Learning+filetype:pdf
#
# Subspace Outlier Detection in Linear Time with Randomized Hashing
# <br> Saket Sathe and Charu Aggarwal <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Sathe+and+Charu+Aggarwal+Subspace+Outlier+Detection+in+Linear+Time+with+Randomized+Hashing+filetype:pdf
#
# Sequential Ensemble Learning for Outlier Detection: A Bias-Variance Perspective
# <br> Shebuti Rayana, Wen Zhong, and Leman Akoglu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Rayana%2C+Wen+Zhong%2C+and+Leman+Akoglu+Sequential+Ensemble+Learning+for+Outlier+Detection%3A+A+Bias-Variance+filetype:pdf
#
# Outlier Detection from Network Data with Subnetwork Interpretation
# <br> Xuan-Hong Dang, Arllei Silva, Ambuj K Singh, Prithwish Basu, and Ananthram Swami <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Dang%2C+Arllei+Silva%2C+Ambuj+K+Singh%2C+Prithwish+Basu%2C+and+Ananthram+Swami+Outlier+Detection+from+filetype:pdf
#
# Sparse Gaussian Markov Random Field Mixtures for Anomaly Detection
# <br> Tsuyoshi Ide, Ankush Khandelwal, and Jayant Kalagnanam <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Ide%2C+Ankush+Khandelwal%2C+and+Jayant+Kalagnanam+Sparse+Gaussian+Markov+Random+Field+Mixtures+for+Anomaly+filetype:pdf
#
# Low-Rank Sparse Feature Selection for Patient Similarity Learning
# <br> Mengting Zhan, Shilei Cao, Shiyu Chang, Jishang Wei, and Buyue Qian <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhan%2C+Shilei+Cao%2C+Shiyu+Chang%2C+Jishang+Wei%2C+and+Buyue+Qian+Low-Rank+Sparse+Feature+Selection+filetype:pdf
#
# Structure-Preserved Multi-Source Domain Adaptation
# <br> Hongfu Liu, Ming Shao, and Yun Fu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Liu%2C+Ming+Shao%2C+and+Yun+Fu+Structure-Preserved+Multi-Source+Domain+Adaptation+filetype:pdf
#
# Gaussian Component based Index for GMMs
# <br> Linfei Zhou, Bianca Wackersreuther, Frank Fiedler, Claudia Plant, and Christian Boehm <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhou%2C+Bianca+Wackersreuther%2C+Frank+Fiedler%2C+Claudia+Plant%2C+and+Christian+Boehm+Gaussian+Component+based+Index+filetype:pdf
#
#
# <br><br><h3> A6: SEQUENCES AND TIME SERIES </h3>
# <br>
# Time Series Motifs: Exploiting a Novel Algorithm and GPUs to break the one Hundred Million Barrier
# <br> Yan Zhu, Zachary Zimmerman, Nader Shakibay Senobari, Chin-Chia Michael Yeh, Gareth Funning, Abdullah Mueen, Philip Brisk, and Eamonn Keogh <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhu%2C+Zachary+Zimmerman%2C+Nader+Shakibay+Senobari%2C+Chin-Chia+Michael+Yeh%2C+Gareth+Funning%2C+Abdullah+Mueen%2C+Philip+filetype:pdf
#
# Visualization of Salient Subsequences in Time Series
# <br> Chin-Chia Michael Yeh, Helga Van Herle, and Eamonn Keogh <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Michael+Yeh%2C+Helga+Van+Herle%2C+and+Eamonn+Keogh+Visualization+of+Salient+Subsequences+in+Time+filetype:pdf
#
# Fast Warping Distance for Sparse Time Series
# <br> Abdullah Mueen, Nikan Chavoshi, Noor Abu-El-Rub, Hossein Hamooni, and Amanda Minnich <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Mueen%2C+Nikan+Chavoshi%2C+Noor+Abu-El-Rub%2C+Hossein+Hamooni%2C+and+Amanda+Minnich+Fast+Warping+Distance+for+filetype:pdf
#
# Frequent Sequence Mining with Subsequence Constraints
# <br> Kaustubh Beedkar and Rainer Gemulla <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Beedkar+and+Rainer+Gemulla+Frequent+Sequence+Mining+with+Subsequence+Constraints+filetype:pdf
#
# Second-order Online Active Learning and Its Applications
# <br> Shuji Hao, Peilin Zhao, Jing Lu, Steven C.H. Hoi, and Chunyan Miao <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Hao%2C+Peilin+Zhao%2C+Jing+Lu%2C+Steven+C.H.+Hoi%2C+and+Chunyan+Miao+Second-order+Online+Active+filetype:pdf
#
# HIVE-COTE: The Hierarchical Vote Collective of Transformation-based Ensembles for Time Series Classification
# <br> Jason Lines, Sarah Taylor, and Anthony Bagnall <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Lines%2C+Sarah+Taylor%2C+and+Anthony+Bagnall+HIVE-COTE%3A+The+Hierarchical+Vote+Collective+of+Transformation-based+Ensembles+filetype:pdf
#
# All Pairs Similarity Joins for Time Series Subsequences
# <br> Chin-Chia Michael Yeh, Yan Zhu, Liudmila Ulanova, Nurjahan Begum, Yifei Ding, Hoang Anh Dau, Diego Silva, Abdullah Mueen, and Eamonn Keogh <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Michael+Yeh%2C+Yan+Zhu%2C+Liudmila+Ulanova%2C+Nurjahan+Begum%2C+Yifei+Ding%2C+Hoang+Anh+Dau%2C+Diego+filetype:pdf
#
# Prefix and Suffix Invariant Dynamic Time Warping
# <br> Diego Silva, Gustavo E.A.P.A. Batista, and Eamonn Keogh <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Silva%2C+Gustavo+E.A.P.A.+Batista%2C+and+Eamonn+Keogh+Prefix+and+Suffix+Invariant+Dynamic+Time+Warping+filetype:pdf
#
# Dynamic Poisson Factor Analysis
# <br> Yizhe Zhang, Ricardo Henao, and Lawrence Carin <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang%2C+Ricardo+Henao%2C+and+Lawrence+Carin+Dynamic+Poisson+Factor+Analysis+filetype:pdf
#
#
# <br><br><h3> B6: BIOMEDICAL </h3>
# <br>
# Predicting COPD Failure by Modeling Hazard in Longitudinal Clinical Data
# <br> Jianfei Zhang, Shengrui Wang, Josiane Courteau, Lifei Chen, and Alain Vanasse <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang%2C+Shengrui+Wang%2C+Josiane+Courteau%2C+Lifei+Chen%2C+and+Alain+Vanasse+Predicting+COPD+Failure+by+filetype:pdf
#
# Measuring Patient Similarities via A Deep Architecture with Medical Concept Embedding
# <br> Zihao Zhu, Changchang Yin, Yu Cheng, Jishang Wei, and Buyue Qian <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhu%2C+Changchang+Yin%2C+Yu+Cheng%2C+Jishang+Wei%2C+and+Buyue+Qian+Measuring+Patient+Similarities+via+filetype:pdf
#
# New Probabilistic Multi-Graph Decomposition Model to Identify Consistent Human Brain Network Modules
# <br> Heng Huang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Huang+New+Probabilistic+Multi-Graph+Decomposition+Model+to+Identify+Consistent+Human+Brain+Network+Modules+filetype:pdf
#
# Transfer Learning for Survival Analysis via Efficient L2,1-norm Regularized Cox Regression
# <br> Yan Li, Lu Wang, Jie Wang, Jieping Ye, and Chandan Reddy <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Li%2C+Lu+Wang%2C+Jie+Wang%2C+Jieping+Ye%2C+and+Chandan+Reddy+Transfer+Learning+for+Survival+filetype:pdf
#
# New Robust Clustering Model for Identifying Cancer Genome Landscapes
# <br> hongchang gao, Xiaoqian Wang, and Heng Huang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=gao%2C+Xiaoqian+Wang%2C+and+Heng+Huang+New+Robust+Clustering+Model+for+Identifying+Cancer+Genome+filetype:pdf
#
# Efficient Algorithms for the Three Locus Problem in Genome-wide Association Study
# <br> Sanguthevar Rajasekaran and Subrata Saha <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Rajasekaran+and+Subrata+Saha+Efficient+Algorithms+for+the+Three+Locus+Problem+in+Genome-wide+Association+filetype:pdf
#
# Patterns in Cognitive Rehabilitation of Traumatic Brain Injury Patients: A Text Mining Approach
# <br> Alejandro Garcia-Rudolph, Alberto Garcia-Molina, Eloy Opisso, and Josep Maria Tormos <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Garcia-Rudolph%2C+Alberto+Garcia-Molina%2C+Eloy+Opisso%2C+and+Josep+Maria+Tormos+Patterns+in+Cognitive+Rehabilitation+of+filetype:pdf
#
#
# <br><br><h3> TUTORIAL </h3>
# <br>
#
# <br><br><h3> 4 </h3>
# <br>
#
# <br><br><h3> A7: GRAPHS 2 </h3>
# <br>
# On Dense Subgraphs in Signed Network Streams
# <br> Jose Cadena, Anil Vullikanti, and Charu Aggarwal <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Cadena%2C+Anil+Vullikanti%2C+and+Charu+Aggarwal+On+Dense+Subgraphs+in+Signed+Network+Streams+filetype:pdf
#
# Graph-Structured Sparse Optimization for Connected Subgraph Detection
# <br> Baojian Zhou and Feng Chen <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhou+and+Feng+Chen+Graph-Structured+Sparse+Optimization+for+Connected+Subgraph+Detection+filetype:pdf
#
# Hyperbolae Are No Hyperbole: Modelling Communities That Are Not Cliques
# <br> Saskia Metzler, Stephan Günnemann, and Pauli Miettinen <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Metzler%2C+Stephan+G%C3%BCnnemann%2C+and+Pauli+Miettinen+Hyperbolae+Are+No+Hyperbole%3A+Modelling+Communities+That+Are+filetype:pdf
#
# Efficient and scalable detection of overlapping communities in big networks
# <br> Tianshu Lyu, Lidong Bing, Zhao Zhang, and Yan Zhang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Lyu%2C+Lidong+Bing%2C+Zhao+Zhang%2C+and+Yan+Zhang+Efficient+and+scalable+detection+of+overlapping+filetype:pdf
#
# Mining Summaries for Knowledge Graph Search
# <br> Qi Song, Yinghui Wu and Xin Luna Dong <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Song%2C+Yinghui+Wu+and+Xin+Luna+Dong+Mining+Summaries+for+Knowledge+Graph+Search+filetype:pdf
#
# MeGS: Partitioning Meaningful Subgraph Structures using Minimum Description Length
# <br> Sebastian Goebl, Annika Tonch, Christian Böhm, and Claudia Plant <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Goebl%2C+Annika+Tonch%2C+Christian+B%C3%B6hm%2C+and+Claudia+Plant+MeGS%3A+Partitioning+Meaningful+Subgraph+Structures+using+filetype:pdf
#
# Learning from your network of friends: a trajectory representation learning model based on online social ties
# <br> Basma Alharbi and Xiangliang Zhang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Alharbi+and+Xiangliang+Zhang+Learning+from+your+network+of+friends%3A+a+trajectory+representation+learning+filetype:pdf
#
#
# <br><br><h3> B7: DISTRIBUTED AND HIGH PERFORMANCE COMPUTING </h3>
# <br>
# Partition Aware Connected Component Computation in Distributed Systems
# <br> Ha-Myung Park, Namyong Park, Sung-Hyon Myaeng, and U Kang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Park%2C+Namyong+Park%2C+Sung-Hyon+Myaeng%2C+and+U+Kang+Partition+Aware+Connected+Component+Computation+in+filetype:pdf
#
# Efficient Distributed SGD with Variance Reduction
# <br> Soham De and Thomas Goldstein <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=De+and+Thomas+Goldstein+Efficient+Distributed+SGD+with+Variance+Reduction+filetype:pdf
#
# HogWild++: A New Mechanism for Decentralized Asynchronous Stochastic Gradient Descent
# <br> Huan Zhang, Cho-Jui Hsieh, and Venkatesh Akella <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang%2C+Cho-Jui+Hsieh%2C+and+Venkatesh+Akella+HogWild%2B%2B%3A+A+New+Mechanism+for+Decentralized+Asynchronous+Stochastic+filetype:pdf
#
# Spectrum-Revealing Cholesky Factorization for Kernel Methods
# <br> Jianwei Xiao and Ming Gu <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Xiao+and+Ming+Gu+Spectrum-Revealing+Cholesky+Factorization+for+Kernel+Methods+filetype:pdf
#
# Efficient and Distributed Algorithms for Large-Scale Generalized Canonical Correlations Analysis
# <br> Xiao Fu, Kejun Huang, Evangelos Papalexakis, Hyun Ah Song, Partha Talukdar, Nicholas Sidiropoulos, Christos Faloutsos, and Tom Mitchell <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Fu%2C+Kejun+Huang%2C+Evangelos+Papalexakis%2C+Hyun+Ah+Song%2C+Partha+Talukdar%2C+Nicholas+Sidiropoulos%2C+Christos+Faloutsos%2C+filetype:pdf
#
# One-pass Logistic Regression for Label-drift and Large-scale Classification on Distributed Systems
# <br> Vu Nguyen, Tu Dinh Nguyen, Trung Le, Dinh Phung, and Svetha Venkatesh <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Nguyen%2C+Tu+Dinh+Nguyen%2C+Trung+Le%2C+Dinh+Phung%2C+and+Svetha+Venkatesh+One-pass+Logistic+Regression+filetype:pdf
#
# A Fast Distributed Classification Algorithm for Large-scale Imbalanced Data
# <br> Huihui Wang, Yang Gao, Yinghuan Shi, and Hao Wang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Yang+Gao%2C+Yinghuan+Shi%2C+and+Hao+Wang+A+Fast+Distributed+Classification+Algorithm+for+filetype:pdf
#
#
# <br><br><h3> C7: SUPERVISED LEARNING 2 </h3>
# <br>
# Binary Classifier Calibration using an Ensemble of Near Isotonic Regression Models
# <br> Mahdi Pakdaman Naeini and Gregory Cooper <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Pakdaman+Naeini+and+Gregory+Cooper+Binary+Classifier+Calibration+using+an+Ensemble+of+Near+Isotonic+filetype:pdf
#
# Fixing the Convergence Problems in Parallel Asynchronous Dual Coordinate Descent
# <br> Huan Zhang and Cho-Jui Hsieh <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang+and+Cho-Jui+Hsieh+Fixing+the+Convergence+Problems+in+Parallel+Asynchronous+Dual+Coordinate+Descent+filetype:pdf
#
# Learning Task Relational Structure for Multi-Task Feature Learning
# <br> De Wang, Feiping Nie, and Heng Huang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Feiping+Nie%2C+and+Heng+Huang+Learning+Task+Relational+Structure+for+Multi-Task+Feature+Learning+filetype:pdf
#
# Scalable Discrete Supervised Hash Learning with Asymmetric Matrix Factorization
# <br> Shifeng Zhang, Jianmin Li, Jinma Guo, and Bo Zhang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang%2C+Jianmin+Li%2C+Jinma+Guo%2C+and+Bo+Zhang+Scalable+Discrete+Supervised+Hash+Learning+with+filetype:pdf
#
# Budgeted Batch Bayesian Optimization
# <br> Vu Nguyen, Santu Rana, Sunil Gupta, Cheng Li, and Svetha Venkatesh <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Nguyen%2C+Santu+Rana%2C+Sunil+Gupta%2C+Cheng+Li%2C+and+Svetha+Venkatesh+Budgeted+Batch+Bayesian+Optimization+filetype:pdf
#
# Faster Kernels for Graphs with Continuous Attributes via Hashing
# <br> Christopher Morris, Nils M. Kriege, Kristian Kersting, and Petra Mutzel <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Morris%2C+Nils+M.+Kriege%2C+Kristian+Kersting%2C+and+Petra+Mutzel+Faster+Kernels+for+Graphs+with+filetype:pdf
#
# Efficient Sampling-Based Kernel Mean Matching
# <br> Swarup Chandra, Ahsanul Haque, Latifur Khan, and Charu Aggarwal <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Chandra%2C+Ahsanul+Haque%2C+Latifur+Khan%2C+and+Charu+Aggarwal+Efficient+Sampling-Based+Kernel+Mean+Matching+filetype:pdf
#
# Sublinear Dual Coordinate Ascent for Regularized Loss Minimization
# <br> liu liu and Dacheng Tao <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=liu+and+Dacheng+Tao+Sublinear+Dual+Coordinate+Ascent+for+Regularized+Loss+Minimization+filetype:pdf
#
#
# <br><br><h3> TUTORIAL </h3>
# <br>
#
# <br><br><h3> 4 </h3>
# <br>
#
# <br><br><h3> A8: SOCIAL </h3>
# <br>
# Vote-and-Comment: Modeling the Coevolution of User Interactions in Social Voting Web Sites
# <br> Alceu Ferraz Costa, Agma Juci Machado Traina, Caetano Traina Jr., and Christos Faloutsos <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Ferraz+Costa%2C+Agma+Juci+Machado+Traina%2C+Caetano+Traina+Jr.%2C+and+Christos+Faloutsos+Vote-and-Comment%3A+Modeling+filetype:pdf
#
# Homophily, Structure, and Content Augmented Network Representation Learning
# <br> Daokun Zhang, Jie Yin, Xingquan Zhu, and Chengqi Zhang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhang%2C+Jie+Yin%2C+Xingquan+Zhu%2C+and+Chengqi+Zhang+Homophily%2C+Structure%2C+and+Content+Augmented+Network+filetype:pdf
#
# TO BE OR NOT TO BE FRIENDS: Exploiting Social Ties for Venture Investments
# <br> Hao Zhong, Chuanren Liu, Xinjiang Lu, and Hui Xiong <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhong%2C+Chuanren+Liu%2C+Xinjiang+Lu%2C+and+Hui+Xiong+TO+BE+OR+NOT+TO+BE+filetype:pdf
#
# Steering Social Media Promotions with Effective Strategies
# <br> Kun Kuang, Meng Jiang, Peng Cui, and Shiqiang Yang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Kuang%2C+Meng+Jiang%2C+Peng+Cui%2C+and+Shiqiang+Yang+Steering+Social+Media+Promotions+with+Effective+filetype:pdf
#
# HLGPS: A Home Location Global Positioning System in Location-Based Social Networks
# <br> Yulong Gu, Jiaxing Song, Weidong Liu, and Lixin Zou <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Gu%2C+Jiaxing+Song%2C+Weidong+Liu%2C+and+Lixin+Zou+HLGPS%3A+A+Home+Location+Global+Positioning+filetype:pdf
#
# A combinatorial approach to role discovery
# <br> Albert Arockiasamy, Aristides Gionis, and Nikolaj Tatti <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Arockiasamy%2C+Aristides+Gionis%2C+and+Nikolaj+Tatti+A+combinatorial+approach+to+role+discovery+filetype:pdf
#
# HNP3: A Hierarchical Nonparametric Point Process for modeling Content Diffusion Over Social Media
# <br> SeyedAbbas Hosseini, Ali Khodadadi, Ali Arabzadeh, and Hamid R. Rabiee <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Hosseini%2C+Ali+Khodadadi%2C+Ali+Arabzadeh%2C+and+Hamid+R.+Rabiee+HNP3%3A+A+Hierarchical+Nonparametric+Point+filetype:pdf
#
#
# <br><br><h3> B8: STREAMING </h3>
# <br>
# KNN classifier with self adjusting memory for heterogeneous concept drift
# <br> Viktor Losing, Barbara Hammer, and Heiko Wersing <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Losing%2C+Barbara+Hammer%2C+and+Heiko+Wersing+KNN+classifier+with+self+adjusting+memory+for+heterogeneous+filetype:pdf
#
# Streaming Model Selection via Online Factorized Asymptotic Bayesian Inference
# <br> Liu Chunchen, Feng Lu, and Ryohei Fujimaki <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Chunchen%2C+Feng+Lu%2C+and+Ryohei+Fujimaki+Streaming+Model+Selection+via+Online+Factorized+Asymptotic+Bayesian+filetype:pdf
#
# ConTrack: A Scalable Method For Tracking Multiple Concepts In Large Scale Multidimensional Data
# <br> Ali Zonoozi, Qirong Ho, Shonali Krishnaswamy, and Gao Cong <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zonoozi%2C+Qirong+Ho%2C+Shonali+Krishnaswamy%2C+and+Gao+Cong+ConTrack%3A+A+Scalable+Method+For+Tracking+filetype:pdf
#
# ROM: A Robust Online Multi-Task Learning Approach
# <br> CHI ZHANG, PEILIN ZHAO, Shuji Hao, YENG CHAI SOH, and BU SUNG LEE <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=ZHANG%2C+PEILIN+ZHAO%2C+Shuji+Hao%2C+YENG+CHAI+SOH%2C+and+BU+SUNG+LEE+ROM%3A+A+filetype:pdf
#
# Multi-Label Learning with Emerging New Labels
# <br> Yue Zhu, Kai-Ming Ting, and Zhi-Hua Zhou <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Zhu%2C+Kai-Ming+Ting%2C+and+Zhi-Hua+Zhou+Multi-Label+Learning+with+Emerging+New+Labels+filetype:pdf
#
# EXTRACT: Strong Examples from Weakly-Labeled Sensor Data
# <br> Davis Blalock and John Guttag <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Blalock+and+John+Guttag+EXTRACT%3A+Strong+Examples+from+Weakly-Labeled+Sensor+Data+filetype:pdf
#
# Spell: Streaming Parsing of System Event Logs
# <br> Min Du and Feifei Li <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Du+and+Feifei+Li+Spell%3A+Streaming+Parsing+of+System+Event+Logs+filetype:pdf
#
#
# <br><br><h3> C8: SEMI-SUPERVISED AND ACTIVE LEARNING </h3>
# <br>
# Adaptive Neighborhood Propagation by Joint L2,1-norm Regularized Sparse Coding for Representation and Classification
# <br> Lei Jia, Zhao Zhang, Lei Wang, Weiming Jiang, and Mingbo Zhao <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Jia%2C+Zhao+Zhang%2C+Lei+Wang%2C+Weiming+Jiang%2C+and+Mingbo+Zhao+Adaptive+Neighborhood+Propagation+by+filetype:pdf
#
# An Augmented LSTM Framework to Construct Medical Self-diagnosis Android
# <br> Chaochun Liu, Huan Sun, Nan Du, Shulong Tan, Hongliang Fei, Wei Fan, Tao Yang, Hao Wu, Yaliang Li, and Chenwei Zhang <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Liu%2C+Huan+Sun%2C+Nan+Du%2C+Shulong+Tan%2C+Hongliang+Fei%2C+Wei+Fan%2C+Tao+Yang%2C+Hao+filetype:pdf
#
# Semi-Supervised Multi-Label Dimensionality Reduction
# <br> Baolin Guo, Chenping Hou, Feiping Nie, and Dongyun Yi <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Guo%2C+Chenping+Hou%2C+Feiping+Nie%2C+and+Dongyun+Yi+Semi-Supervised+Multi-Label+Dimensionality+Reduction+filetype:pdf
#
# Reliable Semi-supervised Learning
# <br> Junming Shao, Chen Huang, Qinli Yang, and Guangchun Luo <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Shao%2C+Chen+Huang%2C+Qinli+Yang%2C+and+Guangchun+Luo+Reliable+Semi-supervised+Learning+filetype:pdf
#
# A Semi-supervised AUC Optimization Method with Generative Models
# <br> Akinori Fujino and Naonori Ueda <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Fujino+and+Naonori+Ueda+A+Semi-supervised+AUC+Optimization+Method+with+Generative+Models+filetype:pdf
#
# A Novel Uncertainty Sampling Algorithm for Cost-sensitive Multiclass Active Learning
# <br> Kuan-Hao Huang and Hsuan-Tien Lin <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Huang+and+Hsuan-Tien+Lin+A+Novel+Uncertainty+Sampling+Algorithm+for+Cost-sensitive+Multiclass+Active+Learning+filetype:pdf
#
# Can Active Learning Experience Be Transferred?
# <br> Hong-Min Chu and Hsuan-Tien Lin <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Chu+and+Hsuan-Tien+Lin+Can+Active+Learning+Experience+Be+Transferred%3F+filetype:pdf
#
# Incorporating Expert Feedback into Active Anomaly Discovery
# <br> Shubhomoy Das, Weng-Keen Wong, Thomas Dietterich, Alan Fern, and Andrew Emmott <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Das%2C+Weng-Keen+Wong%2C+Thomas+Dietterich%2C+Alan+Fern%2C+and+Andrew+Emmott+Incorporating+Expert+Feedback+into+filetype:pdf

# %%
import urllib2
import re

# %%
conference_schedule = """
11:00 - 13:00
AUDITORIUM
SESSION A1: DEEP LEARNING

Session Chair: Wei Ding (University of Massachusetts Boston, USA)

REGULAR PAPERS:

DM558 "Regularizing Deep Convolutional Neural Networks with a Structured Decorrelation Constraint"
Wei Xiong, Bo Du, Lefei Zhang, and Dacheng Tao

DM613 "Traffic Speed Prediction and Congestion Source Exploration: A Deep Learning Method"
Jingyuan Wang, Qian Gu, Junjie Wu, Guannan Liu, and Zhang Xiong

DM714 "Model Accuracy and Runtime Tradeoff in Distributed Deep Learning: A Systematic Study"
Wei Zhang, Suyog Gupta, and Fei Wang

DM976 "Convolutional MKL Based Multimodal Emotion Recognition and Sentiment Analysis"
Iti Chaturvedi, Soujanya Poria, and Erik Cambria


SHORT PAPERS:

DM390 "Structure Selection for Convolutive Non-negative Matrix Factorization Using Normalized Maximum Likelihood Coding"
Atsushi Suzuki, Kohei Miyaguchi, and Kenji Yamanishi

DM679 "Product-based Neural Networks for User Response Prediction"
Yanru Qu, Han Cai, Kan Ren, Weinan Zhang, and Yong Yu

DM933 "Deep Convolutional Factor Analyser for Multivariate Time Series Modeling"
Chao Yuan

DM945 "Learning Deep Networks from Noisy Labels with Dropout Regularization"
Ishan Jindal, Matthew Nokleby, and Xuewen Chen

11:00-13:00
ROOM A2+A3
SESSION B1: PATTERNS

Session Chair: Jilles Vreeken (MPI, Germany)

REGULAR PAPERS:

DM257 "A Scalable and Generic framework to Mine Top-k Representative Subgraph Patterns" 
Dheepikaa Natarajan and Sayan Ranu 

DM267 "CoreScope: Graph Mining Using k-Core Analysis - Patterns, Anomalies, and Algorithms" 
Kijung Shin, Tina Eliassi-Rad, and Christos Faloutsos 

DM319 "Mining Graphlet Counts in Online Social Networks" 
Xiaowei Chen and John C. S. Lui 

DM912 "On Efficient External-Memory Triangle Listing" 
Yi Cui, Di Xiao, and Dmitri Loguinov 

DM377 "Bi-level Rare Temporal Pattern Detection" 
Dawei Zhou, Jingrui He, Yu Cao, and Jae-sun Seo 

SHORT PAPERS: 

DM1056 "Direct Mining of Subjectively Interesting Relational Patterns" 
Tias Guns, Achille Aknin, Jefrey Lijffijt, and Tijl De Bie 

DM1106 "Mining Statistically Significant Attribute Associations in Attributed Graphs" 
Jihwan Lee, Keehwan Park, and Sunil Prabhakar 
11:00-13:00
ROOM A4
SESSION C1: URBAN AND MOBILITY DATA

Session Chair: Charu Aggarwal (IBM Research, USA)

REGULAR PAPERS:

DM525 "Unsupervised Exceptional Attributed Sub-graph Mining in Urban Data"
Anes Bendimerad, Marc Plantevit, and Céline Robardet

DM535 "POI Recommendation: A Temporal Matching between POI Popularity and User Regularity"
Zijun Yao, Yanjie Fu, Bin Liu, Yanchi Liu, and Hui Xiong

DM649 "The Optimal Distribution of Electric-Vehicle Chargers across A City"
Chen Liu, Ke Deng, Chaojie Li, Jianxin Li, Yanhua Li, and Jun Luo

DM1047 "Relief of Spatiotemporal Accessibility Overloading with Optimal Resource Placement"
Chien-Wei Chang, Hao-Yi Chih, Dean Chou, Yu-Chen Shu, and Kun-Ta Chuang

SHORT PAPERS:

DM365 "The Development of a Smart Taxicab Scheduling System: A Multi-Source Data Fusion Perspective"
Yang Wang, Binxin Liang, Zheng Wei, Liusheng Huang, and Hengchang Liu

DM291 "Regularized Content-Aware Tensor Factorization Meets Temporal-Aware Location Recommendation"
Defu Lian, Zhengyu Zhang, Yong Ge, Fuzheng Zhang, Nicholas Jing Yuan, and Xing Xie

DM268 "Modeling Real Estate for School District Identification"
Fei Tan, Chaoran Cheng, and Zhi Wei

DM1093 "House Price Modeling over Heterogeneous Regions with Hierarchical Spatial Functional Analysis"
Bang Liu, Borislalv Mavrin, Di Niu, and Linglong Kong
11:00-13:00
ROOM A1
TUTORIAL 1

Mining smartphone and mobility data
13:00-14:30
LUNCH BREAK
14:30-16:10
AUDITORIUM
SESSION A2: CLUSTERING

Session Chair: Pauli Mittinen (MPI, Germany)

REGULAR PAPERS:

DM737 "Generalized Independent Subspace Clustering"
Wei Ye, Samuel Maurus, Nina Hubig, and Claudia Plant

DM1021 "Robust Graph-theoretic Clustering Approaches Using Node-Based Resilience Measures"
John Matta, Jeffrey Borwey, Tayo Obafemi-Ajayi, Donald Wunsch, and Gunes Ercal

SHORT PAPERS:

DM396 "Multi-Type Co-clustering of General Heterogeneous Information Networks"
Xianchao Zhang, Haixin Li, Wenxin Liang, and Jiebo Luo

DM565 "Interpretable Clustering via Discriminative Rectangle Mixture Model"
Junxiang Chen, Yale Chang, Brian Hobbs, Peter Castaldi, Michael Cho, Edwin Silverman, and Jennifer Dy

DM577 "Self-Grouping Multi-Network Clustering"
Jingchao Ni, Wei Cheng, Wei Fan, and Xiang Zhang

DM669 "A Theoretical Analysis of the Fuzzy K-Means Problem"
Johannes Blömer, Sascha Brauer, and Kathrin Bujna

DM749 "Multi-View Clustering via Concept Factorization with Local Manifold Regularization"
Hao Wang, Yan Yang, and Tianrui Li

DM972 "Robust Convex Clustering Analysis"
Qi Wang, Pinghua Gong, Shiyu Chang, Thomas Huang, and Jiayu Zhou

14:30-16:10
ROOM A2+A3
SESSION B2: RECOMMENDER SYSTEMS

Session Chair: Nuria Oliver (Data-Pop Alliance, Spain)

REGULAR PAPERS:

DM554 "Efficient Rectangular Maximal-Volume Algorithm for Rating Elicitation in Collaborative Filtering"
Alexander Fonarev, Alexander Mikhalev, Gleb Gusev, Ivan Oseledets, and Pavel Serdyukov

DM635 "Recommending Packages to Groups"
Shuyao Qi, Nikos Mamoulis, Evaggelia Pitoura, and Panayiotis Tsaparas

DM663 "Fusing Similarity Models with Markov Chains for Sparse Sequential Recommendation"
Ruining He and Julian McAuley

SHORT PAPERS:

DM282 "Context-aware Sequential Recommendation"
Qiang Liu, Shu Wu, and Liang Wang

DM692 "Learning Compatibility Across Categories for Heterogeneous Item Recommendation"
Ruining He, Charles Packer, and Julian McAuley

DM773 "Time-Aware User Identification with Topic Models"
Clément Lesaege, François Schnitzler, Anne Lambert, and Jean-Ronan Vigouroux

DM818 "Whether this participant will attract you to this event? Exploiting Participant Influence for Event Recommendation"
Yi Liao, Xinshi Lin, and Wai Lam

14:30-16:10
ROOM A4
SESSION C2: EVENTS AND SOCIAL

Session Chair: Leman Akoglu (CMU, USA)

REGULAR PAPERS:

DM544 "Multi-resolution Spatial Event Forecasting in Social Media"
Liang Zhao, Feng Chen, Chang-Tien Lu, and Naren Ramakrishnan

DM949 "Event Series Prediction via Non-Homogeneous Poisson Process Modelling"
James Goulding, Simon Preston, and Gavin Smith

SHORT PAPERS:

DM729 "Towards Scalable Network Delay Minimization"
Sourav Medya, Petko Bogdanov, and Ambuj K Singh

DM881 "Detecting Change Processes in Dynamic Networks by Frequent Graph Evolution Rule Mining"
Erik Scharwaechter, Marwan Hassani, Emmanuel Mueller, Thomas Seidl, and Jonathan Donges

DM892 "DeBot: Twitter Bot Detection via Warped Correlation"
Nikan Chavoshi, Hossein Hamooni, and Abdullah Mueen

DM1055 "Modeling Knowledge Diffusion with Time Lags in Citation Networks"
Tao-yang Fu, Zhen Lei, and Wang-Chien Lee

DM1062 "Event Grounding from Multimodal Social Network Fusion"
Hyunsouk Cho, Jinyoung Yeo, and Seung-won Hwang

DM1076 "Large-Scale Embedding Learning in Heterogeneous Event Data"
Huan Gui, Jialu Liu, Fangbo Tao, Meng Jiang, Brandon Norick, and Jiawei Han

14:30-16:10
ROOM A1
TUTORIAL 1

Mining smartphone and mobility data
16:10-16:30
COFFEE BREAK
16:30-18:10
AUDITORIUM
SESSION A3: UNSUPERVISED LEARNING

Session Chair: Vagelis Papalexakis (UC Riverside, USA)

REGULAR PAPERS:

DM336 "Iteratively Reweighted Least Squares Algorithms for L1-Norm Principal Component Analysis"
Young Woong Park and Diego Klabjan

DM383 "Heterogeneous Representation Learning with Structured Sparsity Regularization"
Pei Yang and Jingrui He

DM389 "Triply Stochastic Variational Inference for Non-linear Beta Process Factor Analysis"
Kai Fan, Yizhe Zhang, and Katherine Heller

DM821 "Causal Inference by Compression"
Kailash Budhathoki and Jilles Vreeken

SHORT PAPERS:

DM332 "Factorizing Complex Discrete Data "with Finesse""
Samuel Maurus and Claudia Plant

DM337 "A Fast Factorization-based Approach to Robust Principal Component Analysis"
Chong Peng, Zhao Kang, and Qiang Cheng

16:30-18:10
ROOM A2+A3
SESSION B3: CROWDS

Session Chair: Celine Robardet (INSA Lyon, France)

REGULAR PAPERS:

DM460 "A Bayesian Nonparametric Approach to Dynamic Dyadic Data Prediction"
Fengyuan Zhu, Guangyong Chen, and Pheng-Ann Heng

DM615 "Modeling Ambiguity, Subjectivity, and Diverging Viewpoints in Opinion Question Answering Systems"
Mengting Wan and Julian McAuley

DM890 "Group Preference Aggregation: A Nash Equilibrium Approach"
Hongke Zhao, Qi Liu, and Yong Ge

DM1064 "Binding Pairwise Preferences of the Crowd into Rankings: A Thurstonian Approach"
Xiaolong Wang, Jingjing Wang, Jie Luo, Yi Chang, and Chengxiang Zhai

SHORT PAPERS:

DM568 "Improved and Scalable Bradley-Terry Model for Collaborative Ranking"
Jun Hu and Ping li

DM875 "A Robust Framework for Classifying Evolving Document Streams in an Expert-Machine-Crowd Setting"
Muhammad Imran, Sanjay Chawla, and Carlos Castillo

16:30-18:10
ROOM A4
SESSION C3: TEXT

Session Chair: Erik Cambria (NTU, Singapore)

REGULAR PAPERS:

DM1030 "Learning Hierarchically Decomposable Concepts with Active Over-Labeling"
Yuji Mo, Stephen Scott, and Doug Downey

DM1085 "L-EnsNMF: Boosted Local Topic Discovery via Ensemble of Nonnegative Matrix Factorization"
Sangho Suh, Jaegul Choo, Joonseok Lee, and Chandan Reddy

SHORT PAPERS:

DM292 "Mutual Reinforcement of Academic Performance Prediction and Library Book Recommendation"
Defu Lian, Qi Liu, Wenya Zhu, Xing Xie, and Hui Xiong

DM529 "Topic Discovery for Short Texts Using Word Embeddings"
Guangxu Xun, Vishrawas Gopalakrishnan, Fenglong Ma, Yaliang Li, Jing Gao, and Aidong Zhang

DM745 "Concept based Short Text Stream Classification with Topic Drifting Detection"
Peipei Li, Lu He, Xuegang Hu, Yuhong Zhang, Lei Li, and Xindong Wu

DM817 "A Scalable Framework for Stylometric Analysis Query Processing"
Sarana Nutanong, chenyun YU, Raheem Sarwar, Peter Xu, and Dickson Chow

DM897 "Incorporating Pre-Training in Long Short-Term Memory Networks for Tweets Classification"
Shuhan Yuan, Xintao Wu, and Yang Xiang

DM985 "Canonical Consistent Weighted Sampling for Real-Value Weighted Min-Hash"
Wei Wu, Bin Li, Ling Chen, and Chengqi Zhang

16:30-18:10
ROOM A1
TUTORIAL 2

Network Representation Learning: A Revisit in Big Data Era
"""+"""
11:00-13:00
AUDITORIUM
SESSION A4: THEORY

Session Chair: Aris Gionis (Aalto University, Finland)

REGULAR PAPERS:

DM969 "From Sets of Good Redescriptions to Good Sets of Redescriptions"
Janis Kalofolias, Esther Galbrun, and Pauli Miettinen

DM799 "What Will You Gain By Rounding: Theory and Algorithms for Rounding Rank"
Stefan Neumann, Rainer Gemulla, and Pauli Miettinen

DM960 "ADAGIO: Fast Data-aware Near-Isometric Linear Embeddings"
Jaroslaw Blasiok and Charalampos Tsourakakis

DM1003 "Aligned Matrix Completion: Integrating Consistency and Independency in Multiple Domains"
Linli Xu and Zaiyi Chen

DM1037 "Communities in Preference Networks: Refined Axioms and Beyond"
Gang Zeng, Yuyi Wang, Juhua Pu, Xingwu Liu, Xiaoming Sun, and Jialin Zhang

SHORT PAPERS:

DM603 "Foundations of Perturbation Robust Clustering"
Jarrod Moore and Margareta Ackerman

DM360 "Compressing Random Forests"
Amichai Painsky and Saharon Rosset

11:00-13:00
ROOM A4
SESSION C4: WEB

Session Chair: Carlos Castillo (Eurecat, Spain)

REGULAR PAPERS:

DM386 "Reliable Gender Prediction Based on Users' Video Viewing Behavior"
Jie Zhang, Kuang Du, Ruihua Cheng, Zhi Wei, Chenguang Qin, Huaxin You, and Sha Hu

DM733 "Efficient Extraction of Non-negative Latent Factors from High-dimensional and Sparse Matrices"
Xin Luo, Mingsheng Shang, and Shuai Li

DM862 "Inferring latent network from cascade data for dynamic social recommendation"
Qin Zhang, Jia Wu, Peng Zhang, Guodong Long, Ivor W. Tsang, and Chengqi Zhang

DM975 "Sparse Factorization Machines for Click-through Rate Prediction"
Zhen Pan, Qi Liu, Tong Xu, Enhong Chen, Haiping Ma, and Hongjie Lin

SHORT PAPERS:

DM533 "Meta Analyses for Dynamic Contextual Multi Arm Bandits in Display Advertisement"
Hongxia Yang and Quan Lu

DM575 "Selecting Valuable Customers for Merchants in E-commerce Platforms"
Yijun Wang, Le Wu, Zongda Wu, Enhong Chen, and Qi Liu

DM589 "Service Usage Analysis in Mobile Messaging Apps: A Multi-Label Multi-View Perspective"
Hui Xiong, Junming Liu, Xinjiang Lu, Yanjie Fu, and Xiaolin Li

11:00-13:00
ROOM A2+A3
SESSION B4: SUPERVISED LEARNING 1

Session Chair: George Karypis (University of Minnesota, USA)

REGULAR PAPERS:

DM850 "Asynchronous Multi-Task Learning"
Inci Baytas, Ming Yan, Anil Jain, and Jiayu Zhou

DM883 "Interactive Multi-Task Relationship Learning"
Kaixiang Lin and Jiayu Zhou

SHORT PAPERS:

DM433 "Functional Regression with Mode-Sparsity Constraint"
Pei Yang and Jingrui He

DM379 "Learning Supervised Binary Hashing: Optimization vs Diversity"
Ramin Raziperchikolaei and Miguel Carreira-Perpinan

DM732 "Bayesian Rule Sets for Interpretable Classification"
Tong Wang, Cynthia Rudin, Finale Doshi-Velez, Yimin Liu, Erica Klampfl, and Perry MacNeille

DM789 "Probabilistic Formulations of Regression with Mixed Guidance"
Aubrey Gress and Ian Davidson

DM1005 "Background Check: A general technique to build more reliable and versatile classifiers"
Miquel Nieto, Telmo Silva Filho, Meelis Kull, and Peter Flach

DM1026 "Optimizing the Multi-class F-measure via Biconcave Programming"
Weiwei Pan, Harikrishna Narasimhan, Purushottam Kar, Pavlos Protopapas, and Harish Ramaswamy

DM1084 "A Rotation Invariant Latent Factor Model for Moveme Discovery from Static Poses"
Matteo Ruggero Ronchi, Joon Sik Kim, and Yisong Yue

11:00-13:00
ROOM A1
TUTORIAL 3

The Evolution of Natural Language Understanding and Prediction Technologies: from Formal Grammars to Large Scale Machine Learning
13:00-14:30
LUNCH BREAK
14:30-16:10
AUDITORIUM
SESSION A5: GRAPHS 1

Session Chair: Nikolaj Tatti (Aalto University, Finland)

REGULAR PAPERS:

DM424 "Waddling Random Walk: Fast and Accurate Mining of Motif Statistics in Large Graphs"
Guyue Han and Harish Sethu

DM514 "Random Walk with Restart over Dynamic Graphs"
Weiren Yu and Weiren Yu

DM687 "Edge Weight Prediction in Weighted Signed Networks"
Srijan Kumar, Francesca Spezzano, V.S. Subrahmanian, and Christos Faloutsos

SHORT PAPERS:

DM481 "Personalized Ranking in Signed Networks using Signed Random Walk with Restart"
Jinhong Jung, Woojeong Jin, Sael Lee, and U Kang

DM864 "Asymptotic Analysis of Equivalences and Core-Structures in Kronecker-Style Graph Models"
Alex Chin, Timothy Goodrich, Michael O'Brien, Felix Reidl, Blair Sullivan, and Drew van der Poel

DM328 "Fractality of Massive Graphs: Scalable Analysis with Sketch-Based Box-Covering Algorithm"
Takuya Akiba, Kenko Nakamura, and Taro Takaguchi

DM442 "Cut Tree Construction from Massive Graphs"
Takuya Akiba, Yoichi Iwata, Yosuke Sameshima, Naoto Mizuno, and Yosuke Yano

14:30-16:10
ROOM A2+A3
SESSION B5: FEATURE SELECTION

Session Chair: Miguel A. Carreira-Perpinan (UC Merced, USA)

REGULAR PAPERS:

DM327 "Robust Multi-View Feature Selection"
Hongfu Liu, Haiyi Mao, and Yun Fu

DM787 "A Fast Iterative Algorithm for Improved Unsupervised Feature Selection"
Bruno Ordozgoiti, Sandra Gómez Canaval, and Alberto Mozo

DM1065 "Unsupervised Feature Selection for Outlier Detection by Modelling Hierarchical Value-Feature Couplings"
Guansong Pang, Longbing Cao, Ling Chen, and Huan Liu

SHORT PAPERS:

DM380 "Feature Grouping using Weighted l1 norm for High-Dimensional Data"
Bhanukiran Vinzamuri, Karthik Padthe, and Chandan Reddy

DM877 "Toward Time-Evolving Feature Selection on Dynamic Networks"
Jundong Li, Xia Hu, Ling Jian, and Huan Liu

DM997 "Online Unsupervised Multi-view Feature Selection"
Weixiang Shao, Lifang He, Chun-Ta Lu, Xiaokai Wei, and Philip Yu

DM1097 "ExploreKit: Automatic Feature Generation and Selection"
Gilad Katz, Richard Shin, and Dawn Song

14:30-16:10
ROOM A4
SESSION C5: PRIVACY

Session Chair: Tamir Tassa (Open University, Israel)

REGULAR PAPERS:

DM364 "Beyond Points and Paths: Counting Private Bodies"
Maryam Fanaeepour and Benjamin Rubinstein

DM436 "Differentially Private Regression Diagnostics"
Yan Chen, Ashwin Machanavajjhala, Jerome Reiter, and Andres Barrientos

DM767 "Auditing Black-box Models for Indirect Influence"
Philip Adler, Casey Falk, Sorelle Friedler, Gabriel Rybeck, Carlos Schedegger, Brandon Smith, and Suresh Venkatasubramanian

DM769 "College Student Scholarships and Subsidies Granting: A Multi-Modal Multi-Label Approach"
Han-Jia Ye, De-Chuan Zhan, Xiaolin Li, Zhen-Chuan Huang, and Yuan Jiang

SHORT PAPERS:

DM245 "Differential Location Privacy for Sparse Mobile Crowdsensing"
Leye Wang, Daqing Zhang, Dingqi Yang, Brian Y. Lim, and Xiaojuan Ma

DM434 "Scalable Block Scheduling for Efficient Multi-Database Record Linkage"
Thilina Ranbaduge, Dinusha Vatsalan, and Peter Christen

14:30-16:10
ROOM A1
TUTORIAL 3

The Evolution of Natural Language Understanding and Prediction Technologies: from Formal Grammars to Large Scale Machine Learning"""+\
"""
11:00-13:00
ROOM A4
SESSION C6: ANOMALIES AND OUTLIERS

Session Chair: Takashi Washio (Osaka University, Japan)

REGULAR PAPERS:

DM273 "Probabilistic-Mismatch Anomaly Detection: Do one's Medications Match with the Diagnoses?"
Lingxiao Zhang, Xiang Li, Heifeng Liu, Jing Mei, Gang Hu, Junfeng Zhao, Bing Xie, and Guotong Xie

DM274 "Regularized Large Margin Distance Metric Learning"
Ya Li, Xinmei Tian, and Dacheng Tao

DM806 "Subspace Outlier Detection in Linear Time with Randomized Hashing"
Saket Sathe and Charu Aggarwal

SHORT PAPERS:

DM537 "Sequential Ensemble Learning for Outlier Detection: A Bias-Variance Perspective"
Shebuti Rayana, Wen Zhong, and Leman Akoglu

DM925 "Outlier Detection from Network Data with Subnetwork Interpretation"
Xuan-Hong Dang, Arllei Silva, Ambuj K Singh, Prithwish Basu, and Ananthram Swami

DM1044 "Sparse Gaussian Markov Random Field Mixtures for Anomaly Detection"
Tsuyoshi Ide, Ankush Khandelwal, and Jayant Kalagnanam

DM1058 "Low-Rank Sparse Feature Selection for Patient Similarity Learning"
Mengting Zhan, Shilei Cao, Shiyu Chang, Jishang Wei, and Buyue Qian

DM254 "Structure-Preserved Multi-Source Domain Adaptation"
Hongfu Liu, Ming Shao, and Yun Fu

DM938 "Gaussian Component based Index for GMMs"
Linfei Zhou, Bianca Wackersreuther, Frank Fiedler, Claudia Plant, and Christian Boehm

11:00-13:00
AUDITORIUM
SESSION A6: SEQUENCES AND TIME SERIES

Session Chair: Adytia Prakash (Virginia Tech, USA)

REGULAR PAPERS:

DM567 "Time Series Motifs: Exploiting a Novel Algorithm and GPUs to break the one Hundred Million Barrier"
Yan Zhu, Zachary Zimmerman, Nader Shakibay Senobari, Chin-Chia Michael Yeh, Gareth Funning, Abdullah Mueen, Philip Brisk, and Eamonn Keogh

DM248 "Visualization of Salient Subsequences in Time Series"
Chin-Chia Michael Yeh, Helga Van Herle, and Eamonn Keogh

DM920 "Fast Warping Distance for Sparse Time Series"
Abdullah Mueen, Nikan Chavoshi, Noor Abu-El-Rub, Hossein Hamooni, and Amanda Minnich

SHORT PAPERS :

DM295 "Frequent Sequence Mining with Subsequence Constraints"
Kaustubh Beedkar and Rainer Gemulla

DM559 "Second-order Online Active Learning and Its Applications"
Shuji Hao, Peilin Zhao, Jing Lu, Steven C.H. Hoi, and Chunyan Miao

DM1007 "HIVE-COTE: The Hierarchical Vote Collective of Transformation-based Ensembles for Time Series Classification"
Jason Lines, Sarah Taylor, and Anthony Bagnall

DM221 "All Pairs Similarity Joins for Time Series Subsequences"
Chin-Chia Michael Yeh, Yan Zhu, Liudmila Ulanova, Nurjahan Begum, Yifei Ding, Hoang Anh Dau, Diego Silva, Abdullah Mueen, and Eamonn Keogh

DM261 "Prefix and Suffix Invariant Dynamic Time Warping"
Diego Silva, Gustavo E.A.P.A. Batista, and Eamonn Keogh

DM378 "Dynamic Poisson Factor Analysis"
Yizhe Zhang, Ricardo Henao, and Lawrence Carin

11:00-13:00
ROOM A2+A3
SESSION B6: BIOMEDICAL

Session Chair: Shinici Morishita (University of Tokyo, Japan)

REGULAR PAPERS:

DM807 "Predicting COPD Failure by Modeling Hazard in Longitudinal Clinical Data"
Jianfei Zhang, Shengrui Wang, Josiane Courteau, Lifei Chen, and Alain Vanasse

DM1060 "Measuring Patient Similarities via A Deep Architecture with Medical Concept Embedding"
Zihao Zhu, Changchang Yin, Yu Cheng, Jishang Wei, and Buyue Qian

DM1104 "New Probabilistic Multi-Graph Decomposition Model to Identify Consistent Human Brain Network Modules"
Heng Huang

DM373 "Transfer Learning for Survival Analysis via Efficient L2,1-norm Regularized Cox Regression"
Yan Li, Lu Wang, Jie Wang, Jieping Ye, and Chandan Reddy

DM932 "New Robust Clustering Model for Identifying Cancer Genome Landscapes"
hongchang gao, Xiaoqian Wang, and Heng Huang

SHORT PAPERS:

DM489 "Efficient Algorithms for the Three Locus Problem in Genome-wide Association Study"
Sanguthevar Rajasekaran and Subrata Saha

DM626 "Patterns in Cognitive Rehabilitation of Traumatic Brain Injury Patients: A Text Mining Approach"
Alejandro Garcia-Rudolph, Alberto Garcia-Molina, Eloy Opisso, and Josep Maria Tormos

11:00-13:00
ROOM A1
TUTORIAL 4

Core Decomposition of Networks: concepts, algorithms and applications
13:00-14:30
LUNCH BREAK
14:30-16:10
AUDITORIUM
SESSION A7: GRAPHS 2

Session Chair: Esther Galbrun (INRIA, France)

REGULAR PAPERS:

DM422 "On Dense Subgraphs in Signed Network Streams"
Jose Cadena, Anil Vullikanti, and Charu Aggarwal

DM1059 "Graph-Structured Sparse Optimization for Connected Subgraph Detection"
Baojian Zhou and Feng Chen

DM762 "Hyperbolae Are No Hyperbole: Modelling Communities That Are Not Cliques"
Saskia Metzler, Stephan Günnemann, and Pauli Miettinen

SHORT PAPERS:

DM223 "Efficient and scalable detection of overlapping communities in big networks"
Tianshu Lyu, Lidong Bing, Zhao Zhang, and Yan Zhang

DM593 "Mining Summaries for Knowledge Graph Search"
Qi Song, Yinghui Wu and Xin Luna Dong

DM490 "MeGS: Partitioning Meaningful Subgraph Structures using Minimum Description Length"
Sebastian Goebl, Annika Tonch, Christian Böhm, and Claudia Plant

DM1028 "Learning from your network of friends: a trajectory representation learning model based on online social ties"
Basma Alharbi and Xiangliang Zhang

14:30-16:10
ROOM A2+A3
SESSION B7: DISTRIBUTED AND HIGH PERFORMANCE COMPUTING

Session Chair: Alexandre Termier (University of Rennes, France)

REGULAR PAPERS:

DM453 "Partition Aware Connected Component Computation in Distributed Systems"
Ha-Myung Park, Namyong Park, Sung-Hyon Myaeng, and U Kang

DM886 "Efficient Distributed SGD with Variance Reduction"
Soham De and Thomas Goldstein

DM931 "HogWild++: A New Mechanism for Decentralized Asynchronous Stochastic Gradient Descent"
Huan Zhang, Cho-Jui Hsieh, and Venkatesh Akella

SHORT PAPERS:

DM1066 "Spectrum-Revealing Cholesky Factorization for Kernel Methods"
Jianwei Xiao and Ming Gu

DM421 "Efficient and Distributed Algorithms for Large-Scale Generalized Canonical Correlations Analysis"
Xiao Fu, Kejun Huang, Evangelos Papalexakis, Hyun Ah Song, Partha Talukdar, Nicholas Sidiropoulos, Christos Faloutsos, and Tom Mitchell

DM703 "One-pass Logistic Regression for Label-drift and Large-scale Classification on Distributed Systems"
Vu Nguyen, Tu Dinh Nguyen, Trung Le, Dinh Phung, and Svetha Venkatesh

DM708 "A Fast Distributed Classification Algorithm for Large-scale Imbalanced Data"
Huihui Wang, Yang Gao, Yinghuan Shi, and Hao Wang

14:30-16:10
ROOM A4
SESSION C7: SUPERVISED LEARNING 2

Session Chair: Ricard Gavalda (UPC, Spain)

REGULAR PAPERS:

DM966 "Binary Classifier Calibration using an Ensemble of Near Isotonic Regression Models"
Mahdi Pakdaman Naeini and Gregory Cooper

DM1024 "Fixing the Convergence Problems in Parallel Asynchronous Dual Coordinate Descent"
Huan Zhang and Cho-Jui Hsieh

SHORT PAPERS:

DM347 "Learning Task Relational Structure for Multi-Task Feature Learning"
De Wang, Feiping Nie, and Heng Huang

DM562 "Scalable Discrete Supervised Hash Learning with Asymmetric Matrix Factorization"
Shifeng Zhang, Jianmin Li, Jinma Guo, and Bo Zhang

DM691 "Budgeted Batch Bayesian Optimization"
Vu Nguyen, Santu Rana, Sunil Gupta, Cheng Li, and Svetha Venkatesh

DM694 "Faster Kernels for Graphs with Continuous Attributes via Hashing"
Christopher Morris, Nils M. Kriege, Kristian Kersting, and Petra Mutzel

DM922 "Efficient Sampling-Based Kernel Mean Matching"
Swarup Chandra, Ahsanul Haque, Latifur Khan, and Charu Aggarwal

DM1117 "Sublinear Dual Coordinate Ascent for Regularized Loss Minimization"
liu liu and Dacheng Tao

14:30-16:10
ROOM A1
TUTORIAL 4

Core Decomposition of Networks: concepts, algorithms and applications
16:10-16:30
COFFEE BREAK
16:30-18:10
AUDITORIUM
SESSION A8: SOCIAL

Session Chair: Neil Shah (CMU, USA)

REGULAR PAPERS:

DM505 "Vote-and-Comment: Modeling the Coevolution of User Interactions in Social Voting Web Sites"
Alceu Ferraz Costa, Agma Juci Machado Traina, Caetano Traina Jr., and Christos Faloutsos

DM661 "Homophily, Structure, and Content Augmented Network Representation Learning"
Daokun Zhang, Jie Yin, Xingquan Zhu, and Chengqi Zhang

DM805 "TO BE OR NOT TO BE FRIENDS: Exploiting Social Ties for Venture Investments"
Hao Zhong, Chuanren Liu, Xinjiang Lu, and Hui Xiong

SHORT PAPERS:

DM287 "Steering Social Media Promotions with Effective Strategies"
Kun Kuang, Meng Jiang, Peng Cui, and Shiqiang Yang

DM464 "HLGPS: A Home Location Global Positioning System in Location-Based Social Networks"
Yulong Gu, Jiaxing Song, Weidong Liu, and Lixin Zou

DM666 "A combinatorial approach to role discovery"
Albert Arockiasamy, Aristides Gionis, and Nikolaj Tatti

DM995 "HNP3: A Hierarchical Nonparametric Point Process for modeling Content Diffusion Over Social Media"
SeyedAbbas Hosseini, Ali Khodadadi, Ali Arabzadeh, and Hamid R. Rabiee

16:30-18:10
ROOM A2+A3
SESSION B8: STREAMING

Session Chair: Albert Bifet (Télécom ParisTech, France)

REGULAR PAPERS:

DM418 "KNN classifier with self adjusting memory for heterogeneous concept drift"
Viktor Losing, Barbara Hammer, and Heiko Wersing

DM706 "Streaming Model Selection via Online Factorized Asymptotic Bayesian Inference"
Liu Chunchen, Feng Lu, and Ryohei Fujimaki

DM727 "ConTrack: A Scalable Method For Tracking Multiple Concepts In Large Scale Multidimensional Data"
Ali Zonoozi, Qirong Ho, Shonali Krishnaswamy, and Gao Cong

SHORT PAPERS:

DM602 "ROM: A Robust Online Multi-Task Learning Approach"
CHI ZHANG, PEILIN ZHAO, Shuji Hao, YENG CHAI SOH, and BU SUNG LEE

DM676 "Multi-Label Learning with Emerging New Labels"
Yue Zhu, Kai-Ming Ting, and Zhi-Hua Zhou

DM243 "EXTRACT: Strong Examples from Weakly-Labeled Sensor Data"
Davis Blalock and John Guttag

DM456 "Spell: Streaming Parsing of System Event Logs"
Min Du and Feifei Li

16:30-18:10
ROOM A4
SESSION C8: SEMI-SUPERVISED AND ACTIVE LEARNING

Session Chair: Min-Ling Zhang (Southeast University, China) REGULAR PAPERS:
DM500 "Adaptive Neighborhood Propagation by Joint L2,1-norm Regularized Sparse Coding for Representation and Classification"
Lei Jia, Zhao Zhang, Lei Wang, Weiming Jiang, and Mingbo Zhao

DM856 "An Augmented LSTM Framework to Construct Medical Self-diagnosis Android"
Chaochun Liu, Huan Sun, Nan Du, Shulong Tan, Hongliang Fei, Wei Fan, Tao Yang, Hao Wu, Yaliang Li, and Chenwei Zhang

SHORT PAPERS:

DM446 "Semi-Supervised Multi-Label Dimensionality Reduction"
Baolin Guo, Chenping Hou, Feiping Nie, and Dongyun Yi

DM471 "Reliable Semi-supervised Learning"
Junming Shao, Chen Huang, Qinli Yang, and Guangchun Luo

DM601 "A Semi-supervised AUC Optimization Method with Generative Models"
Akinori Fujino and Naonori Ueda

DM725 "A Novel Uncertainty Sampling Algorithm for Cost-sensitive Multiclass Active Learning"
Kuan-Hao Huang and Hsuan-Tien Lin

DM748 "Can Active Learning Experience Be Transferred?"
Hong-Min Chu and Hsuan-Tien Lin

DM893 "Incorporating Expert Feedback into Active Anomaly Discovery"
Shubhomoy Das, Weng-Keen Wong, Thomas Dietterich, Alan Fern, and Andrew Emmott
"""

# %%
regexp_section_split = re.compile('(SESSION|KEYNOTE|TUTORIAL)[ ]')

# %%
sliced_list = re.split(regexp_section_split,conference_schedule)

# %%
len(sliced_list)
# Out:
# 63

# %%
for session_text in sliced_list:
    if not session_text == 'SESSION':
        regexp_session_split = re.compile('\n(DM)([0-9]+)([^\n]*)\n([^\n]+)\n')
        print "\n<br><br><h3>",session_text.split("\n")[0],"</h3>\n<br>"
        sliced_session = re.split(regexp_session_split, session_text)[1:]
        for i,node in enumerate(sliced_session):
            if node=='DM':
                print sliced_session[i+2][2:-1],"\n<br>", sliced_session[i+3],"<br>"
                request = sliced_session[i+3] + " " + sliced_session[i+2][2:-1]
                print("https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=" + \
              "+".join([urllib2.quote(x) for x in request.split(" ")[1:15]])+"+filetype:pdf")
                print("")
# Out:
# <br><br><h3>  </h3>
# <br>
#
# <br><br><h3> A1: DEEP LEARNING </h3>
# <br>
# Regularizing Deep Convolutional Neural Networks with a Structured Decorrelation Constraint
# <br> Wei Xiong, Bo Du, Lefei Zhang, and Dacheng Tao <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Xiong%2C+Bo+Du%2C+Lefei+Zhang%2C+and+Dacheng+Tao+Regularizing+Deep+Convolutional+Neural+Networks+with+filetype:pdf
#
# Traffic Speed Prediction and Congestion Source Exploration: A Deep Learning Method
# <br> Jingyuan Wang, Qian Gu, Junjie Wu, Guannan Liu, and Zhang Xiong <br>
# https://www.google.com/webhp?sourceid=chrome-instant&ion=1&espv=2&ie=UTF-8#q=Wang%2C+Qian+Gu%2C+Junjie+Wu%2C+Guannan+Liu%2C+and+Zhang+Xiong+Traffic+Speed+Prediction+and+filetype:pdf
#
# Model Accuracy and Runtime Tradeoff in Distributed Deep Learning: A Systematic Study
# <br> Wei Zhang, Suyog Gupta, and Fei Wang <br>
# ...

# %%
sliced_session
# Out:
# ['DM',
#  '257',
#  ' "A Scalable and Generic framework to Mine Top-k Representative Subgraph Patterns" ',
#  'Dheepikaa Natarajan and Sayan Ranu ',
#  '',
#  'DM',
#  '267',
#  ' "CoreScope: Graph Mining Using k-Core Analysis - Patterns, Anomalies, and Algorithms" ',
#  'Kijung Shin, Tina Eliassi-Rad, and Christos Faloutsos ',
#  '',
#  'DM',
#  '319',
#  ' "Mining Graphlet Counts in Online Social Networks" ',
#  'Xiaowei Chen and John C. S. Lui ',
#  '',
#  'DM',
#  '912',
#  ' "On Efficient External-Memory Triangle Listing" ',
#  'Yi Cui, Di Xiao, and Dmitri Loguinov ',
#  '',
#  'DM',
#  '377',
#  ' "Bi-level Rare Temporal Pattern Detection" ',
#  'Dawei Zhou, Jingrui He, Yu Cao, and Jae-sun Seo ',
#  '\nSHORT PAPERS: \n',
#  'DM',
#  '1056',
#  ' "Direct Mining of Subjectively Interesting Relational Patterns" ',
#  'Tias Guns, Achille Aknin, Jefrey Lijffijt, and Tijl De Bie ',
#  '',
#  'DM',
#  '1106',
# ...

# %%
paperlist_dict = {sliced_list[i+2]:sliced_list[i+1] for i,term in`a enumerate(sliced_list[:-3]) if term=='href'}

# %% [markdown]
# #### Schedule and papers

# %%
for line in conference_schedule.split("\n"):
    if line[:3] in ["Mon",'Tue','Wed','Thu','Fri','Sat']:
        print("\n")
    
    if line.strip() == 'Break':
        print "\n\n------------\n\n"
    else:
        print line
    
    if line.strip() in paperlist_dict.keys():
        print "https://papers.nips.cc"+paperlist_dict[line]
# Out:
# Tutorial
#
#
# Mon Dec 5th 08:30 -- 10:30 AM @ Rooms 211 + 212
# Deep Reinforcement Learning Through Policy Optimization
# In Tutorials Session C
# Pieter Abbeel · John Schulman
# Tutorial
#
#
# Mon Dec 5th 08:30 -- 10:30 AM @ Area 1 + 2
# Variational Inference: Foundations and Modern Methods
# In Tutorials Session A
# David Blei · Shakir Mohamed · Rajesh Ranganath
# Tutorial
#
#
# Mon Dec 5th 08:30 -- 10:30 AM @ Area 3
# Crowdsourcing: Beyond Label Generation
# In Tutorials Session B
# Jennifer Wortman Vaughan
#
#
# ------------
#
#
#
#
# Mon Dec 5th 10:30 -- 11:00 AM @
# Coffee Break
# Tutorial
#
#
# Mon Dec 5th 11:00 AM -- 01:00 PM @ Rooms 211 + 212
# Theory and Algorithms for Forecasting Non-Stationary Time Series
# In Tutorials Session C
# Vitaly Kuznetsov · Mehryar Mohri
# Tutorial
#
#
# Mon Dec 5th 11:00 AM -- 01:00 PM @ Area 1 + 2
# Nuts and Bolts of Building AI systems using Deep Learning
# In Tutorials Session A
# Andrew Y Ng
# Tutorial
#
#
# ...
